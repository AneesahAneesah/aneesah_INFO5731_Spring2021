# %% [markdown]
# <a href="https://colab.research.google.com/github/AneesahAneesah/aneesah_INFO5731_Spring2021/blob/main/INFO5731_Assignm_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1: Understand N-gram
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the noun phrases and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
#used for testing. used to automate web browser interaction from Python

# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
#get update updates the package lists for upgrades for packages that need upgrading
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [49.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [333 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,398 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,995 kB]
# Ign:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [603 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,746 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,425 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [894 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,165 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [363 kB]
# Fetched 12.2 MB in 4s (3,457 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 83.2 MB of archives.
# After this operation, 282 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 89.0.4389.82-0ubuntu0.18.04.1 [1,127 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 89.0.4389.82-0ubuntu0.18.04.1 [73.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 89.0.4389.82-0ubuntu0.18.04.1 [3,800 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 89.0.4389.82-0ubuntu0.18.04.1 [4,697 kB]
# Fetched 83.2 MB in 3s (24.7 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_89.0.4389.82-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (89.0.4389.82-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (89.0.4389.82-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 5.5MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')  #invoking chrome in a headless mode(execution of full version of chrome)
options.add_argument('-no-sandbox') #used to permit or restrict modules
options.add_argument('-disable-dev-shm-usage') #shared virtual memory system specific device drivers and programs

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait  #wait tells WebDriver to poll the DOM(Document Object Model) 
from selenium.webdriver.common.by import By
import pandas as pd
import time
#for a certain amount of time when trying to find any element not immediately available

driver = webdriver.Chrome('chromedriver',options=options)
reviews_link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'

arr_T= []
arr_R = []
driver.get(reviews_link)

for i in range(4):

  driver.find_element_by_class_name("ipl-load-more__button").click() #using class name name to find the appropritae elements
  time.sleep(5)
  Tit = driver.find_elements(By.CLASS_NAME, "title") #finding elements that are used as title of the review
  Rev = driver.find_elements(By.CLASS_NAME, "text") #finsing elements that is the text of the reviews

for ele, sub_ele in zip(Tit, Rev):

      arr_T.append((ele.text).replace('\n',''))
      arr_R.append(sub_ele.text)

#zip() is used to iterate elements from two or more iterables
df = pd.DataFrame(list(zip(arr_T, arr_R)), columns =['Title of the Review', 'The Review'])
print("Length of data frame: {0}".format(len(df)))

#printing the data in the dataframe

df
# Out:
# Length of data frame: 125
#                                    Title of the Review                                         The Review
# 0    Outstanding movie with a haunting performance ...  Every once in a while a movie comes, that trul...
# 1                       Only certain people can relate  This is a movie that only those who have felt ...
# 2                             Perfect in every aspect.  Truly a masterpiece, The Best Hollywood film o...
# 3                                        MASTERPIECE 😍  Joaquin Phoenix gives a tour de force performa...
# 4                                     The Hype is real  Most of the time movies are anticipated like t...
# ..                                                 ...                                                ...
# 120  Went into this blind, and i didnt enjoy it at ...  I didnt really know much about this movie. I h...
# 121                                              Great
# 122                                 Very Disappointing  Film was directed and produced poorly. Opportu...
# 123  By far the best DC movie to date, Joaquin Phoe...  Wow, what a movie! I have to admit, When I fir...
# 124                                     Not real Joker  This movie is poorly done as to how it tells t...
#
# [125 rows x 2 columns]

# %%
import nltk
nltk.download()

#building programs that use human language.
#natural language toolkit
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
#Lowercase
df['Reviews after coverting into Lower Case'] = df['The Review'].apply(lambda y: " ".join(y.lower() for y in y.split()))

# %%
#Punctuation
df['Reviews after removing Punctuation'] = df['Reviews after coverting into Lower Case'].str.replace('[^\w\s]','')

# %%
#removing stopwords
#importing stopwords collection from nltk
#already existing stopwords

from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Reviews after removing StopWords'] = df['Reviews after removing Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
import re
df['Reviews after removing Special Characters'] = df['Reviews after removing Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

# %%
from textblob import TextBlob
df['Correct Spellings'] = df['Reviews after removing Special Characters'].apply(lambda x: str(TextBlob(x).correct()))

# %%
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Correct Spellings'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#stemming
#process of reducing inflection in words to their root forms is stemming
from nltk.stem import PorterStemmer

po_st = PorterStemmer()
df['Stemming'] = df['Tokenization'].apply(lambda x: " ".join([po_st.stem(word) for word in x]))

#Lemmatization is the process of grouping together the different inflected forms of a word so they can be analysed as a single item

from textblob import Word
import nltk

nltk.download('wordnet')
df['Lemmatization'] = df['Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/imdb_joker_review.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

sent = []
for sentence in df['Lemmatization']:
  sent.append(word_tokenize(sentence))
af_clean = [x for x in sent if x != []]
iterate = list(itertools.chain.from_iterable(af_clean))

# %%
df
# Out:
#                                    Title of the Review  ...                                      Lemmatization
# 0    Outstanding movie with a haunting performance ...  ...  everi onc in a while a movi come that truli ma...
# 1                       Only certain people can relate  ...  thi is a movi that onli those who have felt al...
# 2                             Perfect in every aspect.  ...  truli a masterpiec the best hollywood film of ...
# 3                                        MASTERPIECE 😍  ...  joaquin phoenix give a tour de forc perform fe...
# 4                                     The Hype is real  ...  most of the time move are anticip like thi the...
# ..                                                 ...  ...                                                ...
# 120  Went into this blind, and i didnt enjoy it at ...  ...  i didn realli know much about thi movi i hadn ...
# 121                                              Great  ...
# 122                                 Very Disappointing  ...  film wa direct and produc poorli opportun to t...
# 123  By far the best DC movie to date, Joaquin Phoe...  ...  now what a movi i have to admit when i first h...
# 124                                     Not real Joker  ...  thi movi is poorli done a to how it tell the s...
#
# [125 rows x 11 columns]

# %%
tri_grams = nltk.trigrams(iterate)
freq_dist = nltk.FreqDist(tri_grams)
freq_dist
# Out:
# FreqDist({('everi', 'onc', 'in'): 1,
#           ('onc', 'in', 'a'): 1,
#           ('in', 'a', 'while'): 1,
#           ('a', 'while', 'a'): 1,
#           ('while', 'a', 'movi'): 1,
#           ('a', 'movi', 'come'): 1,
#           ('movi', 'come', 'that'): 1,
#           ('come', 'that', 'truli'): 1,
#           ('that', 'truli', 'make'): 1,
#           ('truli', 'make', 'an'): 1,
#           ('make', 'an', 'impact'): 1,
#           ('an', 'impact', 'joaquin'): 1,
#           ('impact', 'joaquin', 'perform'): 1,
#           ('joaquin', 'perform', 'and'): 1,
#           ('perform', 'and', 'scenographi'): 1,
#           ('and', 'scenographi', 'in'): 1,
#           ('scenographi', 'in', 'all'): 1,
#           ('in', 'all', 'it'): 1,
#           ('all', 'it', 'brillianc'): 1,
#           ('it', 'brillianc', 'grotesqu'): 1,
#           ('brillianc', 'grotesqu', 'hunt'): 1,
#           ('grotesqu', 'hunt', 'and'): 1,
#           ('hunt', 'and', 'cring'): 1,
#           ('and', 'cring', 'hard'): 1,
#           ('cring', 'hard', 'to'): 1,
#           ('hard', 'to', 'watch'): 1,
#           ('to', 'watch', 'at'): 1,
#           ('watch', 'at', 'time'): 1,
#           ('at', 'time', 'but'): 2,
#           ('time', 'but', 'so'): 1,
#           ('but', 'so', 'mesmer'): 1,
#           ('so', 'mesmer', 'you'): 1,
#           ('mesmer', 'you', 'wont'): 1,
#           ('you', 'wont', 'blink'): 1,
#           ('wont', 'blink', 'an'): 1,
#           ('blink', 'an', 'eye'): 1,
#           ('an', 'eye', 'watch'): 1,
#           ('eye', 'watch', 'it'): 1,
#           ('watch', 'it', 'tragic'): 1,
#           ('it', 'tragic', 'but'): 1,
#           ('tragic', 'but', 'with'): 1,
#           ('but', 'with', 'serious'): 1,
#           ('with', 'serious', 'funni'): 1,
#           ('serious', 'funni', 'moment'): 1,
#           ('funni', 'moment', 'emot'): 1,
#           ('moment', 'emot', 'rollercoast'): 1,
#           ('emot', 'rollercoast', 'sometim'): 1,
#           ('rollercoast', 'sometim', 'with'): 1,
#           ('sometim', 'with', 'multipl'): 1,
#           ('with', 'multipl', 'emot'): 1,
#           ('multipl', 'emot', 'pop'): 1,
#           ('emot', 'pop', 'at'): 1,
#           ('pop', 'at', 'the'): 1,
#           ('at', 'the', 'same'): 1,
#           ('the', 'same', 'time'): 1,
#           ('same', 'time', 'thi'): 1,
#           ('time', 'thi', 'is'): 1,
#           ('thi', 'is', 'far'): 2,
#           ('is', 'far', 'from'): 2,
#           ('far', 'from', 'a'): 3,
#           ('from', 'a', 'typic'): 1,
#           ('a', 'typic', 'actionriddl'): 1,
#           ('typic', 'actionriddl', 'predict'): 1,
#           ('actionriddl', 'predict', 'superhero'): 1,
#           ('predict', 'superhero', 'movi'): 1,
#           ('superhero', 'movi', 'it'): 2,
#           ('movi', 'it', 'a'): 2,
#           ('it', 'a', 'proper'): 1,
#           ('a', 'proper', 'psycholog'): 1,
#           ('proper', 'psycholog', 'thrillerdrama'): 1,
#           ('psycholog', 'thrillerdrama', 'with'): 1,
#           ('thrillerdrama', 'with', 'the'): 1,
#           ('with', 'the', 'singl'): 1,
#           ('the', 'singl', 'best'): 1,
#           ('singl', 'best', 'charact'): 1,
#           ('best', 'charact', 'develop'): 1,
#           ('charact', 'develop', 'i'): 1,
#           ('develop', 'i', 'have'): 1,
#           ('i', 'have', 'ever'): 3,
#           ('have', 'ever', 'seen'): 3,
#           ('ever', 'seen', 'thi'): 1,
#           ('seen', 'thi', 'is'): 1,
#           ('thi', 'is', 'a'): 9,
#           ('is', 'a', 'movi'): 2,
#           ('a', 'movi', 'that'): 2,
#           ('movi', 'that', 'onli'): 1,
#           ('that', 'onli', 'those'): 1,
#           ('onli', 'those', 'who'): 1,
#           ('those', 'who', 'have'): 1,
#           ('who', 'have', 'felt'): 1,
#           ('have', 'felt', 'alon'): 1,
#           ('felt', 'alon', 'and'): 1,
#           ('alon', 'and', 'isol'): 1,
#           ('and', 'isol', 'can'): 1,
#           ('isol', 'can', 'truli'): 1,
#           ('can', 'truli', 'relat'): 1,
#           ('truli', 'relat', 'to'): 1,
#           ('relat', 'to', 'it'): 2,
#           ('to', 'it', 'you'): 1,
#           ('it', 'you', 'understand'): 1,
#           ('you', 'understand', 'the'): 1,
#           ('understand', 'the', 'motiv'): 1,
#           ('the', 'motiv', 'and'): 1,
#           ('motiv', 'and', 'you'): 1,
#           ('and', 'you', 'feel'): 1,
#           ('you', 'feel', 'sorri'): 1,
#           ('feel', 'sorri', 'for'): 2,
#           ('sorri', 'for', 'the'): 2,
#           ('for', 'the', 'charact'): 1,
#           ('the', 'charact', 'a'): 1,
#           ('charact', 'a', 'lot'): 1,
#           ('a', 'lot', 'of'): 8,
#           ('lot', 'of', 'peopl'): 2,
#           ('of', 'peopl', 'will'): 1,
#           ('peopl', 'will', 'see'): 1,
#           ('will', 'see', 'thi'): 1,
#           ('see', 'thi', 'movi'): 3,
#           ('thi', 'movi', 'and'): 4,
#           ('movi', 'and', 'think'): 1,
#           ('and', 'think', 'that'): 1,
#           ('think', 'that', 'it'): 2,
#           ('that', 'it', 'encourag'): 1,
#           ('it', 'encourag', 'violenc'): 1,
#           ('encourag', 'violenc', 'but'): 1,
#           ('violenc', 'but', 'truli'): 1,
#           ('but', 'truli', 'thi'): 1,
#           ('truli', 'thi', 'movi'): 1,
#           ('thi', 'movi', 'should'): 2,
#           ('movi', 'should', 'encourag'): 1,
#           ('should', 'encourag', 'each'): 1,
#           ('encourag', 'each', 'and'): 1,
#           ('each', 'and', 'everi'): 1,
#           ('and', 'everi', 'one'): 1,
#           ('everi', 'one', 'of'): 1,
#           ('one', 'of', 'u'): 1,
#           ('of', 'u', 'to'): 1,
#           ('u', 'to', 'becom'): 1,
#           ('to', 'becom', 'a'): 2,
#           ('becom', 'a', 'better'): 1,
#           ('a', 'better', 'person'): 1,
#           ('better', 'person', 'treat'): 1,
#           ('person', 'treat', 'everyon'): 1,
#           ('treat', 'everyon', 'with'): 1,
#           ('everyon', 'with', 'respect'): 1,
#           ('with', 'respect', 'and'): 1,
#           ('respect', 'and', 'make'): 1,
#           ('and', 'make', 'each'): 1,
#           ('make', 'each', 'other'): 1,
#           ('each', 'other', 'feel'): 1,
#           ('other', 'feel', 'like'): 1,
#           ('feel', 'like', 'they'): 1,
#           ('like', 'they', 'belong'): 1,
#           ('they', 'belong', 'in'): 1,
#           ('belong', 'in', 'thi'): 1,
#           ('in', 'thi', 'world'): 1,
#           ('thi', 'world', 'instead'): 1,
#           ('world', 'instead', 'of'): 1,
#           ('instead', 'of', 'make'): 1,
#           ('of', 'make', 'them'): 1,
#           ('make', 'them', 'feel'): 1,
#           ('them', 'feel', 'isol'): 1,
#           ('feel', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'a'): 1,
#           ('truli', 'a', 'masterpiec'): 1,
#           ('a', 'masterpiec', 'the'): 1,
#           ('masterpiec', 'the', 'best'): 1,
#           ('the', 'best', 'hollywood'): 1,
#           ('best', 'hollywood', 'film'): 1,
#           ('hollywood', 'film', 'of'): 1,
#           ('film', 'of', '2019'): 1,
#           ('of', '2019', 'one'): 1,
#           ('2019', 'one', 'of'): 1,
#           ('one', 'of', 'the'): 15,
#           ('of', 'the', 'best'): 8,
#           ('the', 'best', 'film'): 3,
#           ('best', 'film', 'of'): 2,
#           ('film', 'of', 'the'): 6,
#           ('of', 'the', 'decad'): 2,
#           ('the', 'decad', 'and'): 1,
#           ('decad', 'and', 'truli'): 1,
#           ('and', 'truli', 'the'): 1,
#           ('truli', 'the', 'best'): 1,
#           ('best', 'film', 'to'): 1,
#           ('film', 'to', 'bring'): 1,
#           ('to', 'bring', 'a'): 2,
#           ('bring', 'a', 'comic'): 1,
#           ('a', 'comic', 'book'): 2,
#           ('comic', 'book', 'so'): 1,
#           ('book', 'so', 'willingli'): 1,
#           ('so', 'willingli', 'and'): 1,
#           ('willingli', 'and', 'realist'): 1,
#           ('and', 'realist', 'to'): 1,
#           ('realist', 'to', 'real'): 1,
#           ('to', 'real', 'if'): 1,
#           ('real', 'if', 'remark'): 1,
#           ('if', 'remark', 'direct'): 1,
#           ('remark', 'direct', 'cinematographi'): 1,
#           ('direct', 'cinematographi', 'music'): 1,
#           ('cinematographi', 'music', 'and'): 1,
#           ('music', 'and', 'the'): 1,
#           ('and', 'the', 'act'): 3,
#           ('the', 'act', 'some'): 1,
#           ('act', 'some', 'peopl'): 1,
#           ('some', 'peopl', 'are'): 1,
#           ('peopl', 'are', 'surpris'): 1,
#           ('are', 'surpris', 'to'): 1,
#           ('surpris', 'to', 'find'): 1,
#           ('to', 'find', 'it'): 1,
#           ('find', 'it', 'disturb'): 1,
#           ('it', 'disturb', 'and'): 1,
#           ('disturb', 'and', 'violent'): 1,
#           ('and', 'violent', 'but'): 1,
#           ('violent', 'but', 'it'): 1,
#           ('but', 'it', 'a'): 1,
#           ('it', 'a', 'necess'): 1,
#           ('a', 'necess', 'and'): 1,
#           ('necess', 'and', 'messag'): 1,
#           ('and', 'messag', 'it'): 1,
#           ('messag', 'it', 'about'): 1,
#           ('it', 'about', 'societi'): 1,
#           ('about', 'societi', 'and'): 1,
#           ('societi', 'and', 'reflect'): 1,
#           ('and', 'reflect', 'those'): 1,
#           ('reflect', 'those', 'underappreciatedunrecognizedbulli'): 1,
#           ('those', 'underappreciatedunrecognizedbulli', 'peopl'): 1,
#           ('underappreciatedunrecognizedbulli', 'peopl', 'prove'): 1,
#           ('peopl', 'prove', 'they'): 1,
#           ('prove', 'they', 'can'): 1,
#           ('they', 'can', 'do'): 1,
#           ('can', 'do', 'someth'): 1,
#           ('do', 'someth', 'too'): 1,
#           ('someth', 'too', 'the'): 1,
#           ('too', 'the', 'way'): 1,
#           ('the', 'way', 'it'): 1,
#           ('way', 'it', 'show'): 1,
#           ('it', 'show', 'class'): 1,
#           ('show', 'class', 'differ'): 1,
#           ('class', 'differ', 'corrupt'): 1,
#           ('differ', 'corrupt', 'and'): 1,
#           ('corrupt', 'and', 'how'): 1,
#           ('and', 'how', 'rich'): 1,
#           ('how', 'rich', 'and'): 1,
#           ('rich', 'and', 'talent'): 1,
#           ('and', 'talent', 'rule'): 1,
#           ('talent', 'rule', 'other'): 1,
#           ('rule', 'other', 'around'): 1,
#           ('other', 'around', 'them'): 1,
#           ('around', 'them', 'is'): 1,
#           ('them', 'is', 'not'): 1,
#           ('is', 'not', 'exagger'): 1,
#           ('not', 'exagger', 'and'): 1,
#           ('exagger', 'and', 'that'): 1,
#           ('and', 'that', 'what'): 1,
#           ('that', 'what', 'make'): 1,
#           ('what', 'make', 'it'): 2,
#           ('make', 'it', 'differ'): 1,
#           ('it', 'differ', 'it'): 1,
#           ('differ', 'it', 'believ'): 1,
#           ('it', 'believ', 'there'): 1,
#           ('believ', 'there', 'could'): 1,
#           ('there', 'could', 'be'): 1,
#           ('could', 'be', 'multipl'): 1,
#           ('be', 'multipl', 'joke'): 1,
#           ('multipl', 'joke', 'live'): 1,
#           ('joke', 'live', 'in'): 1,
#           ('live', 'in', 'our'): 1,
#           ('in', 'our', 'societi'): 2,
#           ('our', 'societi', 'that'): 2,
#           ('societi', 'that', 'could'): 1,
#           ('that', 'could', 'shake'): 1,
#           ('could', 'shake', 'those'): 1,
#           ('shake', 'those', 'around'): 1,
#           ('those', 'around', 'them'): 1,
#           ('around', 'them', 'in'): 1,
#           ('them', 'in', 'much'): 1,
#           ('in', 'much', 'bitter'): 1,
#           ('much', 'bitter', 'way'): 1,
#           ('bitter', 'way', 'than'): 1,
#           ('way', 'than', 'the'): 1,
#           ('than', 'the', 'film'): 1,
#           ('the', 'film', 'show'): 1,
#           ('film', 'show', 'make'): 1,
#           ('show', 'make', 'peopl'): 1,
#           ('make', 'peopl', 'comfort'): 1,
#           ('peopl', 'comfort', 'peopl'): 1,
#           ('comfort', 'peopl', 'consid'): 1,
#           ('peopl', 'consid', 'thi'): 1,
#           ('consid', 'thi', 'a'): 1,
#           ('thi', 'a', 'wake'): 1,
#           ('a', 'wake', 'up'): 2,
#           ('wake', 'up', 'call'): 2,
#           ('up', 'call', 'a'): 1,
#           ('call', 'a', 'messag'): 1,
#           ('a', 'messag', 'but'): 1,
#           ('messag', 'but', 'first'): 1,
#           ('but', 'first', 'a'): 1,
#           ('first', 'a', 'film'): 1,
#           ('a', 'film', 'a'): 1,
#           ('film', 'a', 'perfect'): 1,
#           ('a', 'perfect', 'film'): 1,
#           ('perfect', 'film', 'joaquin'): 1,
#           ('film', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'give'): 2,
#           ('phoenix', 'give', 'a'): 1,
#           ('give', 'a', 'tour'): 1,
#           ('a', 'tour', 'de'): 1,
#           ('tour', 'de', 'forc'): 1,
#           ('de', 'forc', 'perform'): 1,
#           ('forc', 'perform', 'fearless'): 1,
#           ('perform', 'fearless', 'and'): 1,
#           ('fearless', 'and', 'stun'): 1,
#           ('and', 'stun', 'in'): 1,
#           ('stun', 'in', 'it'): 1,
#           ('in', 'it', 'emot'): 1,
#           ('it', 'emot', 'depth'): 1,
#           ('emot', 'depth', 'and'): 1,
#           ('depth', 'and', 'physic'): 1,
#           ('and', 'physic', 'it'): 1,
#           ('physic', 'it', 'imposs'): 1,
#           ('it', 'imposs', 'to'): 1,
#           ('imposs', 'to', 'talk'): 1,
#           ('to', 'talk', 'about'): 1,
#           ('talk', 'about', 'thi'): 1,
#           ('about', 'thi', 'without'): 1,
#           ('thi', 'without', 'referenc'): 1,
#           ('without', 'referenc', 'heath'): 1,
#           ('referenc', 'heath', 'ledger'): 1,
#           ('heath', 'ledger', 'oscarwin'): 1,
#           ('ledger', 'oscarwin', 'perform'): 1,
#           ('oscarwin', 'perform', 'from'): 1,
#           ('perform', 'from', 'the'): 1,
#           ('from', 'the', 'dark'): 1,
#           ('the', 'dark', 'knight'): 8,
#           ('dark', 'knight', 'wide'): 1,
#           ('knight', 'wide', 'consid'): 1,
#           ('wide', 'consid', 'the'): 1,
#           ('consid', 'the', 'definit'): 1,
#           ('the', 'definit', 'liveact'): 1,
#           ('definit', 'liveact', 'portray'): 1,
#           ('liveact', 'portray', 'of'): 1,
#           ('portray', 'of', 'the'): 2,
#           ('of', 'the', 'joke'): 11,
#           ('the', 'joke', 'so'): 1,
#           ('joke', 'so', 'let'): 1,
#           ('so', 'let', 'talk'): 1,
#           ('let', 'talk', 'about'): 1,
#           ('talk', 'about', 'it'): 1,
#           ('about', 'it', 'the'): 1,
#           ('it', 'the', 'fact'): 1,
#           ('the', 'fact', 'is'): 1,
#           ('fact', 'is', 'everyon'): 1,
#           ('is', 'everyon', 'is'): 1,
#           ('everyon', 'is', 'go'): 1,
#           ('is', 'go', 'to'): 1,
#           ('go', 'to', 'be'): 3,
#           ('to', 'be', 'stun'): 1,
#           ('be', 'stun', 'by'): 1,
#           ('stun', 'by', 'what'): 1,
#           ('by', 'what', 'phoenix'): 1,
#           ('what', 'phoenix', 'accomplish'): 1,
#           ('phoenix', 'accomplish', 'becaus'): 1,
#           ('accomplish', 'becaus', 'it'): 1,
#           ('becaus', 'it', 'what'): 1,
#           ('it', 'what', 'mani'): 1,
#           ('what', 'mani', 'thought'): 1,
#           ('mani', 'thought', 'imposs'): 1,
#           ('thought', 'imposs', 'a'): 1,
#           ('imposs', 'a', 'portray'): 1,
#           ('a', 'portray', 'that'): 1,
#           ('portray', 'that', 'match'): 1,
#           ('that', 'match', 'and'): 1,
#           ('match', 'and', 'potenti'): 1,
#           ('and', 'potenti', 'exce'): 1,
#           ('potenti', 'exce', 'that'): 1,
#           ('exce', 'that', 'of'): 1,
#           ('that', 'of', 'the'): 2,
#           ('of', 'the', 'dark'): 1,
#           ('dark', 'knight', 'clown'): 1,
#           ('knight', 'clown', 'princ'): 1,
#           ('clown', 'princ', 'of'): 3,
#           ('princ', 'of', 'crime'): 3,
#           ('of', 'crime', 'most'): 1,
#           ('crime', 'most', 'of'): 1,
#           ('most', 'of', 'the'): 4,
#           ('of', 'the', 'time'): 2,
#           ('the', 'time', 'move'): 1,
#           ('time', 'move', 'are'): 1,
#           ('move', 'are', 'anticip'): 1,
#           ('are', 'anticip', 'like'): 1,
#           ('anticip', 'like', 'thi'): 1,
#           ('like', 'thi', 'they'): 1,
#           ('thi', 'they', 'end'): 1,
#           ('they', 'end', 'up'): 1,
#           ('end', 'up', 'fall'): 1,
#           ('up', 'fall', 'short'): 1,
#           ('fall', 'short', 'way'): 1,
#           ('short', 'way', 'short'): 1,
#           ('way', 'short', 'joke'): 1,
#           ('short', 'joke', 'is'): 1,
#           ('joke', 'is', 'the'): 3,
#           ('is', 'the', 'first'): 2,
#           ('the', 'first', 'time'): 4,
#           ('first', 'time', 'i'): 1,
#           ('time', 'i', 'wa'): 1,
#           ('i', 'wa', 'more'): 1,
#           ('wa', 'more', 'than'): 1,
#           ('more', 'than', 'happi'): 1,
#           ('than', 'happi', 'with'): 1,
#           ('happi', 'with', 'the'): 1,
#           ('with', 'the', 'hope'): 1,
#           ('the', 'hope', 'plea'): 1,
#           ('hope', 'plea', 'ignor'): 1,
#           ('plea', 'ignor', 'the'): 1,
#           ('ignor', 'the', 'complaint'): 1,
#           ('the', 'complaint', 'of'): 1,
#           ('complaint', 'of', 'pernici'): 1,
#           ('of', 'pernici', 'violenc'): 1,
#           ('pernici', 'violenc', 'a'): 1,
#           ('violenc', 'a', 'they'): 1,
#           ('a', 'they', 'are'): 1,
#           ('they', 'are', 'embarrass'): 1,
#           ('are', 'embarrass', 'to'): 1,
#           ('embarrass', 'to', 'say'): 1,
#           ('to', 'say', 'the'): 1,
#           ('say', 'the', 'least'): 1,
#           ('the', 'least', 'we'): 1,
#           ('least', 'we', 'haven'): 1,
#           ('we', 'haven', 'seen'): 1,
#           ('haven', 'seen', 'a'): 1,
#           ('seen', 'a', 'comic'): 1,
#           ('a', 'comic', 'movi'): 1,
#           ('comic', 'movi', 'thi'): 1,
#           ('movi', 'thi', 'real'): 1,
#           ('thi', 'real', 'befor'): 1,
#           ('real', 'befor', 'if'): 1,
#           ('befor', 'if', 'we'): 1,
#           ('if', 'we', 'ever'): 1,
#           ('we', 'ever', 'deserv'): 1,
#           ('ever', 'deserv', 'a'): 1,
#           ('deserv', 'a', 'better'): 1,
#           ('a', 'better', 'class'): 1,
#           ('better', 'class', 'of'): 1,
#           ('class', 'of', 'crimin'): 1,
#           ('of', 'crimin', 'phillip'): 1,
#           ('crimin', 'phillip', 'and'): 1,
#           ('phillip', 'and', 'phoenix'): 1,
#           ('and', 'phoenix', 'have'): 1,
#           ('phoenix', 'have', 'deliv'): 1,
#           ('have', 'deliv', 'thi'): 1,
#           ('deliv', 'thi', 'is'): 1,
#           ('thi', 'is', 'dark'): 1,
#           ('is', 'dark', 'joke'): 1,
#           ('dark', 'joke', 'is'): 1,
#           ('joke', 'is', 'dark'): 1,
#           ('is', 'dark', 'and'): 2,
#           ('dark', 'and', 'you'): 1,
#           ('and', 'you', 'will'): 4,
#           ('you', 'will', 'fall'): 1,
#           ('will', 'fall', 'in'): 1,
#           ('fall', 'in', 'love'): 2,
#           ('in', 'love', 'with'): 2,
#           ('love', 'with', 'the'): 1,
#           ('with', 'the', 'villain'): 1,
#           ('the', 'villain', 'a'): 1,
#           ('villain', 'a', 'you'): 1,
#           ('a', 'you', 'should'): 1,
#           ('you', 'should', 'the'): 1,
#           ('should', 'the', 'bad'): 1,
#           ('the', 'bad', 'gun'): 1,
#           ('bad', 'gun', 'are'): 1,
#           ('gun', 'are', 'alway'): 1,
#           ('are', 'alway', 'more'): 1,
#           ('alway', 'more', 'romant'): 1,
#           ('more', 'romant', 'anyway'): 1,
#           ('romant', 'anyway', 'let'): 1,
#           ('anyway', 'let', 'me'): 1,
#           ('let', 'me', 'start'): 1,
#           ('me', 'start', 'off'): 1,
#           ('start', 'off', 'by'): 1,
#           ('off', 'by', 'say'): 1,
#           ('by', 'say', 'if'): 1,
#           ('say', 'if', 'joaquin'): 1,
#           ('if', 'joaquin', 'phoenix'): 3,
#           ('joaquin', 'phoenix', 'doesn'): 2,
#           ('phoenix', 'doesn', 'get'): 1,
#           ('doesn', 'get', 'hi'): 1,
#           ('get', 'hi', 'oscar'): 1,
#           ('hi', 'oscar', 'for'): 1,
#           ('oscar', 'for', 'thi'): 2,
#           ('for', 'thi', 'movi'): 6,
#           ('thi', 'movi', 'then'): 1,
#           ('movi', 'then', 'the'): 1,
#           ('then', 'the', 'scar'): 1,
#           ('the', 'scar', 'should'): 1,
#           ('scar', 'should', 'be'): 1,
#           ('should', 'be', 'cancel'): 1,
#           ('be', 'cancel', 'phoenix'): 1,
#           ('cancel', 'phoenix', 'is'): 1,
#           ('phoenix', 'is', 'amaz'): 1,
#           ('is', 'amaz', 'a'): 1,
#           ('amaz', 'a', 'you'): 1,
#           ('a', 'you', 'might'): 1,
#           ('you', 'might', 'heard'): 1,
#           ('might', 'heard', 'from'): 1,
#           ('heard', 'from', 'everi'): 1,
#           ('from', 'everi', 'review'): 1,
#           ('everi', 'review', 'ever'): 1,
#           ('review', 'ever', 'but'): 1,
#           ('ever', 'but', 'told'): 1,
#           ('but', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'is'): 3,
#           ('phillip', 'is', 'at'): 1,
#           ('is', 'at', 'hi'): 1,
#           ('at', 'hi', 'best'): 1,
#           ('hi', 'best', 'here'): 1,
#           ('best', 'here', 'the'): 1,
#           ('here', 'the', 'stori'): 1,
#           ('the', 'stori', 'line'): 1,
#           ('stori', 'line', 'he'): 1,
#           ('line', 'he', 'take'): 1,
#           ('he', 'take', 'and'): 1,
#           ('take', 'and', 'visual'): 1,
#           ('and', 'visual', 'are'): 1,
#           ('visual', 'are', 'just'): 1,
#           ('are', 'just', 'breathtak'): 1,
#           ('just', 'breathtak', 'the'): 1,
#           ('breathtak', 'the', 'score'): 1,
#           ('the', 'score', 'org'): 1,
#           ('score', 'org', 'the'): 1,
#           ('org', 'the', 'score'): 1,
#           ('the', 'score', 'everi'): 1,
#           ('score', 'everi', 'time'): 1,
#           ('everi', 'time', 'that'): 1,
#           ('time', 'that', 'score'): 1,
#           ('that', 'score', 'came'): 1,
#           ('score', 'came', 'on'): 1,
#           ('came', 'on', 'i'): 1,
#           ('on', 'i', 'felt'): 1,
#           ('i', 'felt', 'veri'): 1,
#           ('felt', 'veri', 'uncomfort'): 1,
#           ('veri', 'uncomfort', 'like'): 1,
#           ('uncomfort', 'like', 'someth'): 1,
#           ('like', 'someth', 'horribl'): 1,
#           ('someth', 'horribl', 'wa'): 1,
#           ('horribl', 'wa', 'about'): 1,
#           ('wa', 'about', 'to'): 1,
#           ('about', 'to', 'happen'): 1,
#           ('to', 'happen', 'it'): 1,
#           ('happen', 'it', 'wa'): 2,
#           ('it', 'wa', 'great'): 1,
#           ('wa', 'great', 'the'): 1,
#           ('great', 'the', 'inspir'): 1,
#           ('the', 'inspir', 'from'): 1,
#           ('inspir', 'from', 'taxi'): 1,
#           ('from', 'taxi', 'driver'): 1,
#           ('taxi', 'driver', 'and'): 3,
#           ('driver', 'and', 'king'): 1,
#           ('and', 'king', 'of'): 1,
#           ('king', 'of', 'comedi'): 4,
#           ('of', 'comedi', 'are'): 1,
#           ('comedi', 'are', 'there'): 1,
#           ('are', 'there', 'and'): 1,
#           ('there', 'and', 'add'): 1,
#           ('and', 'add', 'so'): 1,
#           ('add', 'so', 'much'): 1,
#           ('so', 'much', 'for'): 1,
#           ('much', 'for', 'the'): 1,
#           ('for', 'the', 'movi'): 1,
#           ('the', 'movi', 'and'): 2,
#           ('movi', 'and', 'i'): 2,
#           ('and', 'i', 'got'): 1,
#           ('i', 'got', 'to'): 1,
#           ('got', 'to', 'be'): 1,
#           ('to', 'be', 'honest'): 1,
#           ('be', 'honest', 'there'): 1,
#           ('honest', 'there', 'are'): 1,
#           ('there', 'are', 'scene'): 1,
#           ('are', 'scene', 'that'): 1,
#           ('scene', 'that', 'are'): 2,
#           ('that', 'are', 'veri'): 1,
#           ('are', 'veri', 'violent'): 1,
#           ('veri', 'violent', 'and'): 1,
#           ('violent', 'and', 'it'): 1,
#           ('and', 'it', 'disturb'): 1,
#           ('it', 'disturb', 'but'): 1,
#           ('disturb', 'but', 'i'): 1,
#           ('but', 'i', 'honestli'): 1,
#           ('i', 'honestli', 'expect'): 1,
#           ('honestli', 'expect', 'it'): 1,
#           ('expect', 'it', 'to'): 2,
#           ('it', 'to', 'be'): 4,
#           ('to', 'be', 'wayyyi'): 1,
#           ('be', 'wayyyi', 'more'): 1,
#           ('wayyyi', 'more', 'violent'): 1,
#           ('more', 'violent', 'from'): 1,
#           ('violent', 'from', 'all'): 1,
#           ('from', 'all', 'the'): 2,
#           ('all', 'the', 'controversi'): 1,
#           ('the', 'controversi', 'go'): 1,
#           ('controversi', 'go', 'on'): 1,
#           ('go', 'on', 'overal'): 1,
#           ('on', 'overal', 'thi'): 1,
#           ('overal', 'thi', 'movi'): 1,
#           ('thi', 'movi', 'wa'): 9,
#           ('movi', 'wa', 'great'): 1,
#           ('wa', 'great', 'come'): 1,
#           ('great', 'come', 'oscar'): 1,
#           ('come', 'oscar', 'season'): 1,
#           ('oscar', 'season', 'it'): 1,
#           ('season', 'it', 'need'): 1,
#           ('it', 'need', 'to'): 1,
#           ('need', 'to', 'be'): 2,
#           ('to', 'be', 'nomin'): 1,
#           ('be', 'nomin', 'for'): 1,
#           ('nomin', 'for', 'best'): 1,
#           ('for', 'best', 'pictur'): 1,
#           ('best', 'pictur', 'screenplay'): 1,
#           ('pictur', 'screenplay', 'cinematographi'): 1,
#           ('screenplay', 'cinematographi', 'actor'): 1,
#           ('cinematographi', 'actor', 'score'): 1,
#           ('actor', 'score', 'and'): 1,
#           ('score', 'and', 'director'): 1,
#           ('and', 'director', 'i'): 1,
#           ('director', 'i', 'get'): 1,
#           ('i', 'get', 'whi'): 1,
#           ('get', 'whi', 'some'): 1,
#           ('whi', 'some', 'peopl'): 1,
#           ('some', 'peopl', 'hate'): 1,
#           ('peopl', 'hate', 'thi'): 1,
#           ('hate', 'thi', 'it'): 1,
#           ('thi', 'it', 'becaus'): 1,
#           ('it', 'becaus', 'of'): 1,
#           ('becaus', 'of', 'the'): 1,
#           ('of', 'the', 'polit'): 1,
#           ('the', 'polit', 'messag'): 1,
#           ('polit', 'messag', 'and'): 1,
#           ('messag', 'and', 'how'): 1,
#           ('and', 'how', 'some'): 1,
#           ('how', 'some', 'peopl'): 1,
#           ('some', 'peopl', 'think'): 1,
#           ('peopl', 'think', 'that'): 1,
#           ('think', 'that', 'you'): 1,
#           ('that', 'you', 'need'): 1,
#           ('you', 'need', 'get'): 1,
#           ('need', 'get', 'empti'): 1,
#           ('get', 'empti', 'for'): 1,
#           ('empti', 'for', 'arthur'): 1,
#           ('for', 'arthur', 'mad'): 1,
#           ('arthur', 'mad', 'but'): 1,
#           ('mad', 'but', 'come'): 1,
#           ('but', 'come', 'on'): 1,
#           ('come', 'on', 'that'): 1,
#           ('on', 'that', 'is'): 1,
#           ('that', 'is', 'not'): 1,
#           ('is', 'not', 'the'): 2,
#           ('not', 'the', 'point'): 1,
#           ('the', 'point', 'and'): 1,
#           ('point', 'and', 'it'): 1,
#           ('and', 'it', 'will'): 1,
#           ('it', 'will', 'never'): 1,
#           ('will', 'never', 'be'): 1,
#           ('never', 'be', 'enjoy'): 1,
#           ('be', 'enjoy', 'thi'): 1,
#           ('enjoy', 'thi', 'masterpiec'): 1,
#           ('thi', 'masterpiec', 'becaus'): 1,
#           ('masterpiec', 'becaus', 'joaquin'): 1,
#           ('becaus', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'and'): 1,
#           ('phoenix', 'and', 'told'): 1,
#           ('and', 'told', 'phillip'): 2,
#           ('told', 'phillip', 'overdid'): 1,
#           ('phillip', 'overdid', 'themselv'): 1,
#           ('overdid', 'themselv', 'with'): 1,
#           ('themselv', 'with', 'thi'): 1,
#           ('with', 'thi', 'movi'): 2,
#           ('thi', 'movi', 'the'): 3,
#           ('movi', 'the', 'actingmus'): 1,
#           ('the', 'actingmus', 'and'): 1,
#           ('actingmus', 'and', 'cinematographi'): 1,
#           ('and', 'cinematographi', 'are'): 2,
#           ('cinematographi', 'are', 'just'): 1,
#           ('are', 'just', 'amaz'): 1,
#           ('just', 'amaz', 'plea'): 1,
#           ('amaz', 'plea', 'enjoy'): 1,
#           ('plea', 'enjoy', 'the'): 1,
#           ('enjoy', 'the', 'movi'): 1,
#           ('the', 'movi', 'without'): 1,
#           ('movi', 'without', 'overthink'): 1,
#           ('without', 'overthink', 'it'): 1,
#           ('overthink', 'it', 'i'): 1,
#           ('it', 'i', 'have'): 1,
#           ('i', 'have', 'seen'): 7,
#           ('have', 'seen', 'joke'): 1,
#           ('seen', 'joke', 'yesterday'): 1,
#           ('joke', 'yesterday', 'at'): 1,
#           ('yesterday', 'at', 'venic'): 1,
#           ('at', 'venic', 'an'): 1,
#           ('venic', 'an', 'earli'): 1,
#           ('an', 'earli', 'inflat'): 1,
#           ('earli', 'inflat', 'screen'): 1,
#           ('inflat', 'screen', 'we'): 1,
#           ('screen', 'we', 'had'): 1,
#           ('we', 'had', 'some'): 1,
#           ('had', 'some', 'troubl'): 1,
#           ('some', 'troubl', 'with'): 1,
#           ('troubl', 'with', 'audit'): 1,
#           ('with', 'audit', 'that'): 1,
#           ('audit', 'that', 'lead'): 1,
#           ('that', 'lead', 'to'): 1,
#           ('lead', 'to', 'a'): 1,
#           ('to', 'a', 'nearhour'): 1,
#           ('a', 'nearhour', 'delay'): 1,
#           ('nearhour', 'delay', 'but'): 1,
#           ('delay', 'but', 'it'): 1,
#           ('but', 'it', 'definit'): 2,
#           ('it', 'definit', 'wa'): 1,
#           ('definit', 'wa', 'worth'): 1,
#           ('wa', 'worth', 'it'): 1,
#           ('worth', 'it', 'joke'): 1,
#           ('it', 'joke', 'deserv'): 1,
#           ('joke', 'deserv', 'to'): 1,
#           ('deserv', 'to', 'be'): 2,
#           ('to', 'be', 'present'): 1,
#           ('be', 'present', 'at'): 1,
#           ('present', 'at', 'venic'): 1,
#           ('at', 'venic', 'film'): 1,
#           ('venic', 'film', 'festiv'): 1,
#           ('film', 'festiv', 'an'): 1,
#           ('festiv', 'an', 'event'): 1,
#           ('an', 'event', 'that'): 1,
#           ('event', 'that', 'regard'): 1,
#           ('that', 'regard', 'cinema'): 1,
#           ('regard', 'cinema', 'a'): 1,
#           ('cinema', 'a', 'a'): 1,
#           ('a', 'a', 'form'): 1,
#           ('a', 'form', 'of'): 1,
#           ('form', 'of', 'art'): 1,
#           ('of', 'art', 'becaus'): 1,
#           ('art', 'becaus', 'thi'): 1,
#           ('becaus', 'thi', 'film'): 1,
#           ('thi', 'film', 'is'): 5,
#           ('film', 'is', 'far'): 1,
#           ('from', 'a', 'blockbust'): 1,
#           ('a', 'blockbust', 'or'): 1,
#           ('blockbust', 'or', 'a'): 1,
#           ('or', 'a', 'mere'): 1,
#           ('a', 'mere', 'entertain'): 1,
#           ('mere', 'entertain', 'movi'): 1,
#           ('entertain', 'movi', 'a'): 1,
#           ('movi', 'a', 'most'): 1,
#           ('a', 'most', 'film'): 1,
#           ('most', 'film', 'in'): 1,
#           ('film', 'in', 'the'): 1,
#           ('in', 'the', 'gene'): 2,
#           ('the', 'gene', 'are'): 1,
#           ('gene', 'are', 'it'): 1,
#           ('are', 'it', 'focus'): 1,
#           ('it', 'focus', 'on'): 1,
#           ('focus', 'on', 'the'): 2,
#           ('on', 'the', 'psychic'): 1,
#           ('the', 'psychic', 'of'): 1,
#           ('psychic', 'of', 'the'): 1,
#           ('of', 'the', 'main'): 1,
#           ('the', 'main', 'charact'): 3,
#           ('main', 'charact', 'a'): 1,
#           ('charact', 'a', 'it'): 1,
#           ('a', 'it', 'slowli'): 1,
#           ('it', 'slowli', 'crumbl'): 1,
#           ('slowli', 'crumbl', 'under'): 1,
#           ('crumbl', 'under', 'the'): 1,
#           ('under', 'the', 'pressur'): 1,
#           ('the', 'pressur', 'of'): 1,
#           ('pressur', 'of', 'societi'): 1,
#           ('of', 'societi', 'and'): 1,
#           ('societi', 'and', 'thu'): 1,
#           ('and', 'thu', 'joaquin'): 1,
#           ('thu', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'doe'): 2,
#           ('phoenix', 'doe', 'a'): 2,
#           ('doe', 'a', 'wonder'): 1,
#           ('a', 'wonder', 'perform'): 1,
#           ('wonder', 'perform', 'earn'): 1,
#           ('perform', 'earn', 'almost'): 1,
#           ('earn', 'almost', 'sure'): 1,
#           ('almost', 'sure', 'a'): 1,
#           ('sure', 'a', 'nomin'): 1,
#           ('a', 'nomin', 'at'): 1,
#           ('nomin', 'at', 'the'): 1,
#           ('at', 'the', 'scar'): 1,
#           ('the', 'scar', 'at'): 1,
#           ('scar', 'at', 'least'): 1,
#           ('at', 'least', 'it'): 1,
#           ('least', 'it', 'a'): 1,
#           ('it', 'a', 'take'): 1,
#           ('a', 'take', 'on'): 1,
#           ('take', 'on', 'the'): 6,
#           ('on', 'the', 'joke'): 3,
#           ('the', 'joke', 'that'): 1,
#           ('joke', 'that', 'differ'): 1,
#           ('that', 'differ', 'from'): 1,
#           ('differ', 'from', 'ledger'): 1,
#           ('from', 'ledger', 'but'): 1,
#           ('ledger', 'but', 'id'): 1,
#           ('but', 'id', 'say'): 1,
#           ('id', 'say', 'that'): 1,
#           ('say', 'that', 'both'): 1,
#           ('that', 'both', 'are'): 1,
#           ('both', 'are', 'equal'): 1,
#           ('are', 'equal', 'a'): 1,
#           ('equal', 'a', 'good'): 1,
#           ('a', 'good', 'the'): 1,
#           ('good', 'the', 'main'): 1,
#           ('the', 'main', 'differ'): 1,
#           ('main', 'differ', 'might'): 1,
#           ('differ', 'might', 'be'): 1,
#           ('might', 'be', 'that'): 1,
#           ('be', 'that', 'ledger'): 1,
#           ('that', 'ledger', 'joke'): 1,
#           ('ledger', 'joke', 'is'): 1,
#           ('joke', 'is', 'a'): 2,
#           ('is', 'a', 'ration'): 1,
#           ('a', 'ration', 'that'): 1,
#           ('ration', 'that', 'act'): 1,
#           ('that', 'act', 'insan'): 1,
#           ('act', 'insan', 'while'): 1,
#           ('insan', 'while', 'phoenix'): 1,
#           ('while', 'phoenix', 'is'): 1,
#           ('phoenix', 'is', 'insan'): 1,
#           ('is', 'insan', 'to'): 1,
#           ('insan', 'to', 'the'): 1,
#           ('to', 'the', 'root'): 1,
#           ('the', 'root', 'despit'): 1,
#           ('root', 'despit', 'be'): 1,
#           ('despit', 'be', 'a'): 1,
#           ('be', 'a', 'movi'): 1,
#           ('a', 'movi', 'about'): 3,
#           ('movi', 'about', 'a'): 2,
#           ('about', 'a', 'superhero'): 1,
#           ('a', 'superhero', 'villain'): 1,
#           ('superhero', 'villain', 'joke'): 1,
#           ('villain', 'joke', 'is'): 1,
#           ('joke', 'is', 'much'): 1,
#           ('is', 'much', 'superior'): 1,
#           ('much', 'superior', 'to'): 1,
#           ('superior', 'to', 'most'): 1,
#           ('to', 'most', 'of'): 1,
#           ('of', 'the', 'move'): 1,
#           ('the', 'move', 'of'): 1,
#           ('move', 'of', 'the'): 1,
#           ('of', 'the', 'gene'): 1,
#           ('the', 'gene', 'id'): 1,
#           ('gene', 'id', 'exclud'): 1,
#           ('id', 'exclud', 'the'): 1,
#           ('exclud', 'the', 'dark'): 1,
#           ('dark', 'knight', 'trilog'): 2,
#           ('knight', 'trilog', 'onli'): 1,
#           ('trilog', 'onli', 'but'): 1,
#           ('onli', 'but', 'joke'): 1,
#           ('but', 'joke', 'is'): 2,
#           ('joke', 'is', 'easili'): 1,
#           ('is', 'easili', 'a'): 1,
#           ('easili', 'a', 'good'): 1,
#           ('a', 'good', 'a'): 1,
#           ('good', 'a', 'plan'): 1,
#           ('a', 'plan', 'move'): 1,
#           ('plan', 'move', 'or'): 1,
#           ('move', 'or', 'at'): 1,
#           ('or', 'at', 'least'): 1,
#           ('at', 'least', 'veri'): 1,
#           ('least', 'veri', 'close'): 1,
#           ('veri', 'close', 'it'): 1,
#           ('close', 'it', 'is'): 1,
#           ('it', 'is', 'a'): 8,
#           ('is', 'a', 'smallscal'): 1,
#           ('a', 'smallscal', 'film'): 1,
#           ('smallscal', 'film', 'with'): 1,
#           ('film', 'with', 'a'): 1,
#           ('with', 'a', 'distinct'): 1,
#           ('a', 'distinct', 'style'): 1,
#           ('distinct', 'style', 'and'): 1,
#           ('style', 'and', 'cinematographi'): 1,
#           ('and', 'cinematographi', 'that'): 1,
#           ('cinematographi', 'that', 'can'): 1,
#           ('that', 'can', 'not'): 1,
#           ('can', 'not', 'but'): 1,
#           ('not', 'but', 'be'): 1,
#           ('but', 'be', 'appreci'): 1,
#           ('be', 'appreci', 'and'): 1,
#           ('appreci', 'and', 'a'): 1,
#           ('and', 'a', 'set'): 1,
#           ('a', 'set', 'of'): 1,
#           ('set', 'of', 'veri'): 1,
#           ('of', 'veri', 'cinephil'): 1,
#           ('veri', 'cinephil', 'refer'): 1,
#           ('cinephil', 'refer', 'that'): 1,
#           ('refer', 'that', 'howev'): 1,
#           ('that', 'howev', 'do'): 1,
#           ('howev', 'do', 'not'): 1,
#           ('do', 'not', 'feel'): 1,
#           ('not', 'feel', 'too'): 1,
#           ('feel', 'too', 'forc'): 1,
#           ('too', 'forc', 'or'): 1,
#           ('forc', 'or', 'overlay'): 1,
#           ('or', 'overlay', 'oppress'): 1,
#           ('overlay', 'oppress', 'most'): 1,
#           ('oppress', 'most', 'notabl'): 1,
#           ('most', 'notabl', 'are'): 1,
#           ('notabl', 'are', 'the'): 1,
#           ('are', 'the', 'similar'): 1,
#           ('the', 'similar', 'to'): 1,
#           ('similar', 'to', 'scorses'): 1,
#           ('to', 'scorses', 'taxi'): 1,
#           ('scorses', 'taxi', 'driver'): 1,
#           ('driver', 'and', 'hi'): 1,
#           ('and', 'hi', 'the'): 1,
#           ('hi', 'the', 'king'): 1,
#           ('the', 'king', 'of'): 3,
#           ('of', 'comedi', 'but'): 1,
#           ('comedi', 'but', 'also'): 1,
#           ('but', 'also', 'chain'): 1,
#           ('also', 'chain', 'modern'): 1,
#           ('chain', 'modern', 'time'): 1,
#           ('modern', 'time', 'is'): 1,
#           ('time', 'is', 'somewhat'): 1,
#           ('is', 'somewhat', 'refer'): 1,
#           ('somewhat', 'refer', 'i'): 1,
#           ('refer', 'i', 'am'): 1,
#           ('i', 'am', 'eager'): 1,
#           ('am', 'eager', 'to'): 1,
#           ('eager', 'to', 'see'): 1,
#           ('to', 'see', 'more'): 2,
#           ('see', 'more', 'noncomed'): 1,
#           ('more', 'noncomed', 'effort'): 1,
#           ('noncomed', 'effort', 'by'): 1,
#           ('effort', 'by', 'told'): 1,
#           ('by', 'told', 'phillip'): 3,
#           ('told', 'phillip', 'thi'): 1,
#           ('phillip', 'thi', 'movi'): 1,
#           ('movi', 'wa', 'so'): 2,
#           ('wa', 'so', 'far'): 1,
#           ('so', 'far', 'probabl'): 1,
#           ('far', 'probabl', 'the'): 1,
#           ('probabl', 'the', 'best'): 2,
#           ('the', 'best', 'of'): 1,
#           ('best', 'of', '2019'): 1,
#           ('of', '2019', 'at'): 1,
#           ('2019', 'at', 'worst'): 1,
#           ('at', 'worst', 'contest'): 1,
#           ('worst', 'contest', 'so'): 1,
#           ('contest', 'so', 'far'): 1,
#           ('so', 'far', 'onli'): 1,
#           ('far', 'onli', 'by'): 1,
#           ('onli', 'by', 'door'): 1,
#           ('by', 'door', 'y'): 1,
#           ('door', 'y', 'gloria'): 1,
#           ('y', 'gloria', 'or'): 1,
#           ('gloria', 'or', 'onc'): 1,
#           ('or', 'onc', 'upon'): 1,
#           ('onc', 'upon', 'a'): 2,
#           ('upon', 'a', 'time'): 2,
#           ('a', 'time', 'in'): 2,
#           ('time', 'in', 'hollywood'): 2,
#           ('in', 'hollywood', 'and'): 1,
#           ('hollywood', 'and', 'that'): 1,
#           ('and', 'that', 'should'): 1,
#           ('that', 'should', 'be'): 1,
#           ('should', 'be', 'veri'): 1,
#           ('be', 'veri', 'convinc'): 1,
#           ('veri', 'convinc', 'it'): 1,
#           ('convinc', 'it', 'sad'): 1,
#           ('it', 'sad', 'that'): 1,
#           ('sad', 'that', 'joaquin'): 1,
#           ('that', 'joaquin', 'miss'): 1,
#           ('joaquin', 'miss', 'oscar'): 1,
#           ('miss', 'oscar', 'for'): 1,
#           ('oscar', 'for', 'the'): 1,
#           ('for', 'the', 'gladiat'): 1,
#           ('the', 'gladiat', 'a'): 1,
#           ('gladiat', 'a', 'he'): 1,
#           ('a', 'he', 'wa'): 1,
#           ('he', 'wa', 'veri'): 1,
#           ('wa', 'veri', 'compel'): 1,
#           ('veri', 'compel', 'villain'): 1,
#           ('compel', 'villain', 'but'): 1,
#           ('villain', 'but', 'i'): 1,
#           ('but', 'i', 'am'): 1,
#           ('i', 'am', 'quit'): 1,
#           ('am', 'quit', 'confid'): 1,
#           ('quit', 'confid', 'he'): 1,
#           ('confid', 'he', 'will'): 1,
#           ('he', 'will', 'win'): 1,
#           ('will', 'win', 'it'): 1,
#           ('win', 'it', 'for'): 1,
#           ('it', 'for', 'the'): 1,
#           ('for', 'the', 'joke'): 6,
#           ('the', 'joke', 'damn'): 1,
#           ('joke', 'damn', 'what'): 1,
#           ('damn', 'what', 'a'): 1,
#           ('what', 'a', 'movi'): 2,
#           ('a', 'movi', 'keep'): 1,
#           ...})

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterate)
freq_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(freq_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterate.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('and', 'do'):0.007177033492822967
# ('do', 'i'):0.023255813953488372
# ('like', 'marvel'):0.016129032258064516
# ('marvel', 'is'):0.6666666666666666
# ('better', 'overal'):0.045454545454545456
# ('overal', 'and'):0.14285714285714285
# ('and', 'most'):0.004784688995215311
# ('most', 'move'):0.04
# ('move', 'do'):0.02564102564102564
# ('do', 'put'):0.023255813953488372
# ('out', 'are'):0.03125
# ('are', 'trash'):0.015873015873015872
# ('trash', 'but'):0.5
# ('away', 'my'):0.14285714285714285
# ('my', 'favorit'):0.06060606060606061
# ('favorit', 'comic'):0.3333333333333333
# ('movi', 'even'):0.004310344827586207
# ('even', 'though'):0.06451612903225806
# ('a', 'complet'):0.004048582995951417
# ('complet', 'differ'):0.14285714285714285
# ('differ', 'spin'):0.0625
# ('spin', 'on'):0.5
# ('on', 'comic'):0.014084507042253521
# ('comic', 'move'):0.043478260869565216
# ('to', 'appreci'):0.0060790273556231
# ('the', 'evolut'):0.0013908205841446453
# ('evolut', 'to'):0.3333333333333333
# ('appreci', 'thi'):0.25
# ('it', 'not'):0.03412073490813648
# ('not', 'an'):0.041237113402061855
# ('action', 'movi'):0.058823529411764705
# ('movi', 'but'):0.021551724137931036
# ('realli', 'lip'):0.029411764705882353
# ('lip', 'and'):0.5
# ('and', 'tear'):0.0023923444976076554
# ('tear', 'at'):0.5
# ('the', 'emot'):0.0013908205841446453
# ('emot', 'in'):0.1111111111111111
# ('one', 'movi'):0.0196078431372549
# ('movi', 'while'):0.004310344827586207
# ('while', 'ad'):0.06666666666666667
# ('ad', 'a'):0.5
# ('a', 'wild'):0.0020242914979757085
# ('wild', 'suspens'):0.5
# ('suspens', 'kick'):0.5
# ('kick', 'no'):1.0
# ('no', 'other'):0.0196078431372549
# ('other', 'comic'):0.045454545454545456
# ('movi', 'ha'):0.02586206896551724
# ('ha', 'done'):0.030303030303030304
# ('done', 'that'):0.125
# ('that', 'befor'):0.00510204081632653
# ('befor', 'what'):0.08333333333333333
# ('what', 'an'):0.018518518518518517
# ('an', 'incred'):0.018518518518518517
# ('incred', 'ride'):0.14285714285714285
# ('ride', 'thi'):0.3333333333333333
# ('almost', 'motionless'):0.1
# ('motionless', 'throughout'):1.0
# ('throughout', 'watch'):0.1111111111111111
# ('in', 'awe'):0.005555555555555556
# ('awe', 'the'):1.0
# ('lifetim', 'the'):0.5
# ('the', 'transit'):0.0027816411682892906
# ('transit', 'from'):0.3333333333333333
# ('from', 'troubl'):0.020833333333333332
# ('troubl', 'man'):0.5
# ('man', 'to'):0.18181818181818182
# ('to', 'monster'):0.00303951367781155
# ('monster', 'the'):0.25
# ('the', 'found'):0.0013908205841446453
# ('found', 'score'):0.25
# ('score', 'which'):0.07142857142857142
# ('which', 'directli'):0.038461538461538464
# ('directli', 'drove'):0.5
# ('drove', 'the'):1.0
# ('the', 'goosebump'):0.0013908205841446453
# ('goosebump', 'the'):1.0
# ('cinematographi', 'which'):0.0625
# ('like', 'you'):0.016129032258064516
# ('you', 'were'):0.01020408163265306
# ('were', 'fli'):0.045454545454545456
# ('fli', 'through'):1.0
# ('through', 'gothic'):0.07692307692307693
# ('gothic', 'look'):0.2
# ('look', 'for'):0.16666666666666666
# ('arthur', 'yourself'):0.05555555555555555
# ('yourself', 'and'):0.25
# ('the', 'wast'):0.0013908205841446453
# ('wast', 'de'):0.16666666666666666
# ('de', 'no'):0.8
# ('no', 'who'):0.0196078431372549
# ('who', 'gave'):0.03571428571428571
# ('gave', 'hi'):1.0
# ('hi', 'nod'):0.02
# ('to', 'merri'):0.00303951367781155
# ('merri', 'lewi'):1.0
# ('lewi', 'ignor'):1.0
# ('ignor', 'do'):0.2
# ('do', 'ignor'):0.023255813953488372
# ('ignor', 'batman'):0.2
# ('batman', 'thi'):0.05263157894736842
# ('a', 'work'):0.0020242914979757085
# ('work', 'of'):0.25
# ('art', 'in'):0.14285714285714285
# ('own', 'right'):0.125
# ('right', 'thi'):0.1
# ('movi', 'answer'):0.004310344827586207
# ('answer', 'thi'):0.3333333333333333
# ('thi', 'questionwhat'):0.004366812227074236
# ('questionwhat', 'will'):1.0
# ('will', 'the'):0.02564102564102564
# ('joke', 'be'):0.006211180124223602
# ('be', 'if'):0.008547008547008548
# ('real', 'life'):0.13333333333333333
# ('life', 'charact'):0.05555555555555555
# ('great', 'deep'):0.034482758620689655
# ('deep', 'and'):0.25
# ('move', 'stori'):0.02564102564102564
# ('stori', 'a'):0.05714285714285714
# ('a', 'life'):0.0020242914979757085
# ('life', 'journey'):0.05555555555555555
# ('journey', 'of'):0.5
# ('a', 'man'):0.006072874493927126
# ('man', 'who'):0.18181818181818182
# ('who', 'suffer'):0.03571428571428571
# ('suffer', 'from'):0.2857142857142857
# ('from', 'some'):0.020833333333333332
# ('some', 'psycholog'):0.03225806451612903
# ('psycholog', 'issu'):0.125
# ('issu', 'and'):0.2
# ('how', 'neglect'):0.03333333333333333
# ('neglect', 'build'):0.3333333333333333
# ('build', 'and'):0.1
# ('and', 'rude'):0.0023923444976076554
# ('rude', 'by'):1.0
# ('by', 'other'):0.018518518518518517
# ('other', 'human'):0.045454545454545456
# ('human', 'be'):0.3333333333333333
# ('be', 'can'):0.008547008547008548
# ('can', 'push'):0.024390243902439025
# ('push', 'a'):0.5
# ('to', 'complet'):0.00303951367781155
# ('complet', 'mad'):0.07142857142857142
# ('mad', 'although'):0.16666666666666666
# ('although', 'it'):0.25
# ('not', 'accur'):0.010309278350515464
# ('accur', 'to'):0.25
# ('ani', 'comic'):0.047619047619047616
# ('book', 'adapt'):0.1111111111111111
# ('adapt', 'or'):1.0
# ('or', 'ani'):0.014285714285714285
# ('ani', 'to'):0.047619047619047616
# ('to', 'seri'):0.00303951367781155
# ('seri', 'or'):1.0
# ('or', 'movi'):0.014285714285714285
# ('movi', 'befor'):0.004310344827586207
# ('it', 'yet'):0.0026246719160104987
# ('yet', 'it'):0.14285714285714285
# ('a', 'fresh'):0.0020242914979757085
# ('fresh', 'and'):1.0
# ('and', 'uniqu'):0.0023923444976076554
# ('uniqu', 'take'):0.3333333333333333
# ('crime', 'from'):0.14285714285714285
# ('a', 'realist'):0.0020242914979757085
# ('realist', 'approach'):0.125
# ('approach', 'and'):0.5
# ('believ', 'with'):0.07142857142857142
# ('with', 'joaquin'):0.022727272727272728
# ('phoenix', 'amaz'):0.016129032258064516
# ('amaz', 'perform'):0.07692307692307693
# ('perform', 'a'):0.05
# ('in', 'which'):0.011111111111111112
# ('which', 'he'):0.038461538461538464
# ('he', 'manag'):0.012987012987012988
# ('manag', 'to'):0.5
# ('life', 'lookalik'):0.05555555555555555
# ('lookalik', 'earli'):1.0
# ('earli', 'version'):0.5
# ('joke', 'which'):0.006211180124223602
# ('which', 'although'):0.038461538461538464
# ('although', 'is'):0.25
# ('not', 'comic'):0.010309278350515464
# ('book', 'accur'):0.1111111111111111
# ('accur', 'but'):0.25
# ('feel', 'it'):0.07692307692307693
# ('veri', 'decent'):0.030303030303030304
# ('decent', 'foundat'):0.3333333333333333
# ('foundat', 'for'):1.0
# ('for', 'joke'):0.01680672268907563
# ('joke', '2'):0.006211180124223602
# ('2', 'which'):0.09090909090909091
# ('which', 'should'):0.038461538461538464
# ('be', 'more'):0.02564102564102564
# ('more', 'true'):0.0196078431372549
# ('to', 'heart'):0.00303951367781155
# ('heart', 'of'):1.0
# ('the', 'origin'):0.0013908205841446453
# ('origin', 'version'):0.07692307692307693
# ('our', 'movabl'):0.1111111111111111
# ('movabl', 'villain'):1.0
# ('villain', 'the'):0.14285714285714285
# ('is', 'over'):0.0033333333333333335
# ('over', 'all'):0.07142857142857142
# ('all', 'a'):0.013333333333333334
# ('great', 'piec'):0.034482758620689655
# ('piec', 'of'):0.6666666666666666
# ('of', 'filmmak'):0.003424657534246575
# ('filmmak', 'in'):0.5
# ('it', 'aspect'):0.0026246719160104987
# ('aspect', 'from'):0.25
# ('plot', 'which'):0.05
# ('which', 'wa'):0.11538461538461539
# ('veri', 'interest'):0.030303030303030304
# ('interest', 'believ'):0.125
# ('believ', 'and'):0.14285714285714285
# ('and', 'mani'):0.0023923444976076554
# ('mani', 'can'):0.03225806451612903
# ('can', 'relat'):0.024390243902439025
# ('it', 'through'):0.0026246719160104987
# ('through', 'the'):0.07692307692307693
# ('act', 'which'):0.046511627906976744
# ('wa', 'impress'):0.0070921985815602835
# ('impress', 'splendid'):0.3333333333333333
# ('splendid', 'to'):1.0
# ('the', 'direct'):0.0027816411682892906
# ('direct', 'which'):0.0625
# ('wa', 'outstand'):0.0070921985815602835
# ('outstand', 'my'):0.3333333333333333
# ('my', 'main'):0.030303030303030304
# ('main', 'take'):0.125
# ('of', 'ani'):0.003424657534246575
# ('ani', 'posit'):0.047619047619047616
# ('posit', 'lead'):0.2
# ('lead', 'charact'):0.3333333333333333
# ('i', 'know'):0.00881057268722467
# ('know', 'we'):0.043478260869565216
# ('we', 'live'):0.025
# ('a', 'tough'):0.0020242914979757085
# ('tough', 'world'):1.0
# ('world', 'which'):0.1
# ('which', 'full'):0.038461538461538464
# ('full', 'of'):0.75
# ('of', 'nativ'):0.003424657534246575
# ('nativ', 'but'):1.0
# ('but', 'there'):0.007874015748031496
# ('are', 'some'):0.015873015873015872
# ('some', 'posit'):0.03225806451612903
# ('posit', 'exampl'):0.2
# ('exampl', 'here'):0.25
# ('here', 'and'):0.07692307692307693
# ('and', 'there'):0.0023923444976076554
# ('and', 'to'):0.004784688995215311
# ('to', 'shed'):0.00303951367781155
# ('shed', 'some'):1.0
# ('some', 'light'):0.03225806451612903
# ('light', 'on'):0.25
# ('on', 'one'):0.014084507042253521
# ('or', 'two'):0.02857142857142857
# ('two', 'charact'):0.1111111111111111
# ('movi', 'would'):0.008620689655172414
# ('would', 'been'):0.03225806451612903
# ('a', 'nice'):0.0020242914979757085
# ('nice', 'posit'):0.3333333333333333
# ('posit', 'thought'):0.2
# ('thought', 'the'):0.07142857142857142
# ('movi', 'can'):0.008620689655172414
# ('be', 'misunderstood'):0.008547008547008548
# ('misunderstood', 'by'):0.3333333333333333
# ('by', 'mani'):0.018518518518518517
# ('mani', 'think'):0.03225806451612903
# ('think', 'till'):0.04
# ('till', 'inspir'):0.5
# ('inspir', 'crime'):0.1111111111111111
# ('crime', 'and'):0.2857142857142857
# ('and', 'violenc'):0.0023923444976076554
# ('believ', 'on'):0.07142857142857142
# ('contrari', 'that'):0.5
# ('that', 'mani'):0.00510204081632653
# ('mani', 'who'):0.03225806451612903
# ('who', 'go'):0.03571428571428571
# ('go', 'through'):0.16666666666666666
# ('through', 'hard'):0.07692307692307693
# ('hard', 'life'):0.14285714285714285
# ('life', 'will'):0.05555555555555555
# ('will', 'feel'):0.02564102564102564
# ('feel', 'sympathi'):0.02564102564102564
# ('sympathi', 'for'):1.0
# ('charact', 'other'):0.01639344262295082
# ('other', 'will'):0.045454545454545456
# ('will', 'even'):0.02564102564102564
# ('even', 'relat'):0.03225806451612903
# ('hi', 'miseri'):0.02
# ('miseri', 'and'):0.5
# ('and', 'may'):0.0023923444976076554
# ('may', 'justifi'):0.1111111111111111
# ('justifi', 'hi'):0.25
# ('hi', 'action'):0.02
# ('action', 'i'):0.058823529411764705
# ('believ', 'the'):0.21428571428571427
# ('mani', 'a'):0.03225806451612903
# ('peopl', 'daili'):0.02127659574468085
# ('daili', 'suffer'):1.0
# ('from', 'build'):0.020833333333333332
# ('build', 'racism'):0.1
# ('racism', 'hate'):1.0
# ('hate', 'crime'):0.14285714285714285
# ('crime', 'or'):0.14285714285714285
# ('or', 'neglect'):0.014285714285714285
# ('sometim', 'they'):0.25
# ('they', 'go'):0.06451612903225806
# ('through', 'wors'):0.07692307692307693
# ('wors', 'we'):0.3333333333333333
# ('we', 'should'):0.075
# ('should', 'take'):0.041666666666666664
# ('a', 'deeper'):0.0020242914979757085
# ('deeper', 'look'):0.5
# ('at', 'our'):0.01818181818181818
# ('our', 'action'):0.1111111111111111
# ('action', 'and'):0.11764705882352941
# ('and', 'know'):0.0023923444976076554
# ('know', 'that'):0.17391304347826086
# ('that', 'asid'):0.00510204081632653
# ('asid', 'from'):1.0
# ('from', 'money'):0.020833333333333332
# ('money', 'and'):0.1111111111111111
# ('and', 'author'):0.0023923444976076554
# ('author', 'we'):1.0
# ('we', 'are'):0.05
# ('are', 'all'):0.031746031746031744
# ('all', 'equal'):0.013333333333333334
# ('equal', 'human'):0.3333333333333333
# ('human', 'we'):0.3333333333333333
# ('should', 'treat'):0.041666666666666664
# ('treat', 'one'):0.25
# ('one', 'anoth'):0.0392156862745098
# ('anoth', 'the'):0.14285714285714285
# ('same', 'way'):0.09090909090909091
# ('way', 'we'):0.030303030303030304
# ('we', 'expect'):0.025
# ('expect', 'to'):0.11764705882352941
# ('be', 'treat'):0.008547008547008548
# ('treat', 'joaquin'):0.25
# ('phoenix', 'produc'):0.016129032258064516
# ('produc', 'one'):0.2
# ('most', 'memor'):0.04
# ('memor', 'perform'):1.0
# ('perform', 'ever'):0.025
# ('ever', 'captur'):0.0625
# ('captur', 'in'):0.3333333333333333
# ('a', 'featur'):0.0020242914979757085
# ('featur', 'film'):1.0
# ('film', 'earn'):0.011627906976744186
# ('earn', 'the'):0.3333333333333333
# ('the', 'hardwar'):0.0013908205841446453
# ('hardwar', 'and'):1.0
# ('and', 'accolad'):0.0023923444976076554
# ('accolad', 'he'):1.0
# ('he', 'receiv'):0.012987012987012988
# ('receiv', 'for'):1.0
# ('hi', 'stun'):0.02
# ('stun', 'and'):0.2
# ('disturb', 'portug'):0.1
# ('portug', 'of'):1.0
# ('joke', 'joaquin'):0.012422360248447204
# ('joaquin', 'put'):0.01818181818181818
# ('a', 'virtuou'):0.0020242914979757085
# ('virtuou', 'spotlight'):1.0
# ('spotlight', 'perform'):1.0
# ('and', 'elev'):0.0023923444976076554
# ('elev', 'the'):1.0
# ('to', 'legendari'):0.00303951367781155
# ('legendari', 'statu'):0.25
# ('statu', 'credit'):0.5
# ('credit', 'director'):0.5
# ('director', 'told'):0.125
# ('philip', 'for'):0.3333333333333333
# ('for', 'build'):0.008403361344537815
# ('build', 'tension'):0.1
# ('tension', 'throughout'):1.0
# ('film', 'captur'):0.011627906976744186
# ('captur', 'the'):0.3333333333333333
# ('the', 'glanc'):0.0013908205841446453
# ('glanc', 'of'):1.0
# ('joke', 'tortur'):0.006211180124223602
# ('tortur', 'darksid'):0.5
# ('darksid', 'slide'):1.0
# ('slide', 'into'):1.0
# ('into', 'derang'):0.043478260869565216
# ('derang', 'violent'):1.0
# ('violent', 'insan'):0.125
# ('insan', 'keep'):0.14285714285714285
# ('keep', 'the'):0.08333333333333333
# ('film', 'pace'):0.011627906976744186
# ('and', 'flow'):0.0023923444976076554
# ('flow', 'track'):0.5
# ('track', 'without'):0.5
# ('without', 'unnecessari'):0.07692307692307693
# ('unnecessari', 'fill'):0.25
# ('fill', 'util'):0.3333333333333333
# ('util', 'and'):0.5
# ('and', 'appli'):0.0023923444976076554
# ('appli', 'variou'):1.0
# ('variou', 'camera'):1.0
# ('camera', 'lens'):0.5
# ('lens', 'shot'):1.0
# ('shot', 'angl'):0.5
# ('light', 'colorshu'):0.25
# ('colorshu', 'apertur'):1.0
# ('apertur', 'set'):1.0
# ('set', 'eg'):0.14285714285714285
# ('eg', 'bone'):0.5
# ('bone', 'and'):0.5
# ('scene', 'frame'):0.05555555555555555
# ('frame', 'and'):0.5
# ('and', 'allow'):0.0023923444976076554
# ('allow', 'joaquin'):0.5
# ('joaquin', 'to'):0.01818181818181818
# ('to', 'tap'):0.00303951367781155
# ('tap', 'into'):1.0
# ('into', 'hi'):0.043478260869565216
# ('hi', 'own'):0.04
# ('own', 'dark'):0.125
# ('dark', 'corner'):0.03571428571428571
# ('corner', 'and'):1.0
# ('and', 'util'):0.0023923444976076554
# ('util', 'hi'):0.5
# ('hi', 'uniqu'):0.02
# ('uniqu', 'act'):0.3333333333333333
# ('act', 'instinct'):0.023255813953488372
# ('instinct', 'in'):1.0
# ('in', 'develop'):0.005555555555555556
# ('develop', 'hi'):0.16666666666666666
# ('hi', 'charact'):0.04
# ('charact', 'phoenix'):0.01639344262295082
# ('phoenix', 'act'):0.03225806451612903
# ('act', 'perform'):0.046511627906976744
# ('perform', 'leav'):0.025
# ('leav', 'noth'):0.14285714285714285
# ('noth', 'on'):0.1111111111111111
# ('the', 'tabl'):0.0013908205841446453
# ('tabl', 'if'):1.0
# ('if', 'keep'):0.01818181818181818
# ('keep', 'score'):0.08333333333333333
# ('score', 'phoenix'):0.07142857142857142
# ('phoenix', 'alli'):0.016129032258064516
# ('alli', 'a'):1.0
# ('perfect', '10'):0.09090909090909091
# ('10', 'produc'):0.3333333333333333
# ('produc', 'a'):0.2
# ('a', 'truli'):0.0020242914979757085
# ('truli', 'legendari'):0.14285714285714285
# ('legendari', 'perform'):0.5
# ('perform', 'transform'):0.025
# ('transform', 'the'):0.25
# ('from', 'god'):0.020833333333333332
# ('god', 'know'):0.5
# ('know', 'what'):0.08695652173913043
# ('been', 'with'):0.05263157894736842
# ('with', 'anoth'):0.011363636363636364
# ('anoth', 'actor'):0.14285714285714285
# ('actor', 'to'):0.05555555555555555
# ('910', 'a'):0.5
# ('will', 'not'):0.02564102564102564
# ('not', 'easili'):0.010309278350515464
# ('easili', 'forget'):0.25
# ('forget', 'in'):0.2
# ('in', 'keep'):0.005555555555555556
# ('keep', 'it'):0.16666666666666666
# ('it', 'short'):0.0026246719160104987
# ('short', 'the'):0.14285714285714285
# ('movi', 'suck'):0.004310344827586207
# ('suck', 'ye'):0.3333333333333333
# ('ye', 'i'):0.2
# ('know', 'there'):0.043478260869565216
# ('a', 'need'):0.0020242914979757085
# ('to', 'build'):0.00303951367781155
# ('build', 'charact'):0.1
# ('and', 'cap'):0.0023923444976076554
# ('cap', 'and'):0.3333333333333333
# ('it', 'import'):0.0026246719160104987
# ('import', 'for'):0.16666666666666666
# ('for', 'ani'):0.01680672268907563
# ('ani', 'good'):0.047619047619047616
# ('movi', 'same'):0.004310344827586207
# ('same', 'goe'):0.09090909090909091
# ('goe', 'with'):0.5
# ('thi', 'i'):0.008733624454148471
# ('a', 'troubl'):0.0020242914979757085
# ('man', 'i'):0.09090909090909091
# ('hi', 'frustrat'):0.02
# ('frustrat', 'but'):0.5
# ('need', '2'):0.05555555555555555
# ('movi', 'tell'):0.004310344827586207
# ('same', 'cap'):0.09090909090909091
# ('cap', 'over'):0.3333333333333333
# ('over', 'and'):0.14285714285714285
# ('and', 'over'):0.0023923444976076554
# ('over', 'again'):0.07142857142857142
# ('again', 'give'):0.2
# ('give', 'the'):0.05
# ('guy', 'an'):0.14285714285714285
# ('for', 'perform'):0.008403361344537815
# ('but', 'throw'):0.007874015748031496
# ('throw', 'thi'):0.5
# ('movi', 'into'):0.004310344827586207
# ('the', 'trash'):0.0013908205841446453
# ('trash', 'right'):0.5
# ('right', 'after'):0.1
# ('after', 'joke'):0.1
# ('is', 'liter'):0.0033333333333333335
# ('liter', 'an'):0.2
# ('an', 'achiev'):0.018518518518518517
# ('achiev', 'in'):0.5
# ('in', 'cinemat'):0.005555555555555556
# ('cinemat', 'histori'):1.0
# ('histori', 'there'):0.16666666666666666
# ('no', 'doubt'):0.0392156862745098
# ('doubt', 'in'):0.3333333333333333
# ('that', 'but'):0.01020408163265306
# ('but', 'whi'):0.007874015748031496
# ('peopl', 'compar'):0.02127659574468085
# ('compar', 'it'):0.5
# ('with', 'engag'):0.011363636363636364
# ('engag', 'both'):0.2
# ('both', 'move'):0.16666666666666666
# ('move', 'have'):0.02564102564102564
# ('have', 'their'):0.013888888888888888
# ('own', 'way'):0.125
# ('way', 'and'):0.06060606060606061
# ('and', 'they'):0.007177033492822967
# ('are', 'complet'):0.015873015873015872
# ('differ', 'engag'):0.0625
# ('engag', 'wa'):0.2
# ('best', 'at'):0.03333333333333333
# ('at', 'it'):0.07272727272727272
# ('it', 'gene'):0.0026246719160104987
# ('gene', 'talk'):0.16666666666666666
# ('about', 'joke'):0.03571428571428571
# ('joke', 'what'):0.006211180124223602
# ('what', 'can'):0.05555555555555555
# ('can', 'i'):0.07317073170731707
# ('say', 'a'):0.05555555555555555
# ('a', 'beauti'):0.0020242914979757085
# ('beauti', 'present'):0.5
# ('present', 'of'):0.2
# ('of', 'storylin'):0.003424657534246575
# ('storylin', 'direct'):0.3333333333333333
# ('direct', 'screenplay'):0.0625
# ('screenplay', 'wa'):0.16666666666666666
# ('wa', 'all'):0.0070921985815602835
# ('all', 'at'):0.013333333333333334
# ('it', 'peak'):0.0026246719160104987
# ('peak', 'of'):1.0
# ('great', 'heath'):0.034482758620689655
# ('ledger', 'smile'):0.05
# ('smile', 'down'):0.5
# ('down', 'to'):0.2
# ('to', 'earth'):0.00303951367781155
# ('earth', 'i'):0.5
# ('have', 'never'):0.013888888888888888
# ('never', 'left'):0.07692307692307693
# ('left', 'a'):0.14285714285714285
# ('a', 'review'):0.004048582995951417
# ('review', 'for'):0.08
# ('ani', 'titl'):0.047619047619047616
# ('titl', 'good'):0.2
# ('bad', 'but'):0.05263157894736842
# ('but', 'thi'):0.031496062992125984
# ('is', 'such'):0.0033333333333333335
# ('a', 'piec'):0.0020242914979757085
# ('of', 'garag'):0.003424657534246575
# ('garag', 'that'):0.5
# ('i', 'regist'):0.004405286343612335
# ('regist', 'an'):1.0
# ('an', 'limb'):0.018518518518518517
# ('limb', 'account'):1.0
# ('account', 'just'):1.0
# ('to', 'vent'):0.00303951367781155
# ('vent', 'my'):1.0
# ('opinion', 'i'):0.14285714285714285
# ('i', 'want'):0.013215859030837005
# ('want', 'these'):0.03225806451612903
# ('these', '2'):0.14285714285714285
# ('life', 'back'):0.05555555555555555
# ('back', 'the'):0.2
# ('here', 'are'):0.07692307692307693
# ('are', 'make'):0.015873015873015872
# ('film', 'out'):0.011627906976744186
# ('out', 'to'):0.03125
# ('be', 'far'):0.008547008547008548
# ('far', 'better'):0.14285714285714285
# ('than', 'it'):0.03333333333333333
# ('actual', 'is'):0.09523809523809523
# ('is', 'dont'):0.0033333333333333335
# ('wrong', 'technic'):0.1
# ('technic', 'it'):0.3333333333333333
# ('is', 'extrem'):0.0033333333333333335
# ('extrem', 'well'):0.25
# ('well', 'done'):0.15384615384615385
# ('done', 'and'):0.25
# ('realli', 'quit'):0.029411764705882353
# ('quit', 'extraordinari'):0.09090909090909091
# ('extraordinari', 'he'):0.5
# ('is', 'definit'):0.0033333333333333335
# ('definit', 'look'):0.07692307692307693
# ('at', 'an'):0.01818181818181818
# ('oscar', 'nomin'):0.08695652173913043
# ('nomin', 'but'):0.2
# ('but', 'despit'):0.007874015748031496
# ('despit', 'excel'):0.2
# ('excel', 'write'):0.16666666666666666
# ('write', 'act'):0.1111111111111111
# ('and', 'direct'):0.009569377990430622
# ('direct', 'the'):0.125
# ('is', 'kind'):0.0033333333333333335
# ('kind', 'bore'):0.1111111111111111
# ('it', 'moment'):0.0026246719160104987
# ('moment', 'and'):0.2727272727272727
# ('and', 'sure'):0.0023923444976076554
# ('sure', 'it'):0.08333333333333333
# ('ha', 'some'):0.06060606060606061
# ('some', 'veri'):0.03225806451612903
# ('veri', 'disturb'):0.030303030303030304
# ('disturb', 'element'):0.1
# ('element', 'but'):0.25
# ('a', 'watch'):0.004048582995951417
# ('watch', 'i'):0.022222222222222223
# ('have', 'look'):0.013888888888888888
# ('it', 'mani'):0.0026246719160104987
# ('time', 'a'):0.024390243902439025
# ('a', 'what'):0.004048582995951417
# ('what', 'thi'):0.018518518518518517
# ('film', 'lack'):0.011627906976744186
# ('lack', 'excit'):0.125
# ('excit', 'the'):0.16666666666666666
# ('final', 'act'):0.16666666666666666
# ('is', 'most'):0.006666666666666667
# ('most', 'excel'):0.04
# ('excel', 'but'):0.3333333333333333
# ('felt', 'like'):0.2857142857142857
# ('it', 'took'):0.0026246719160104987
# ('took', 'forev'):0.3333333333333333
# ('forev', 'to'):1.0
# ('i', 'realli'):0.00881057268722467
# ('realli', 'dont'):0.029411764705882353
# ('how', 'so'):0.03333333333333333
# ('mani', 'peopl'):0.03225806451612903
# ('consid', 'it'):0.3333333333333333
# ('i', 'simpli'):0.004405286343612335
# ('simpli', 'hate'):0.25
# ('movi', 'sinc'):0.004310344827586207
# ('sinc', 'the'):0.3333333333333333
# ('veri', 'first'):0.030303030303030304
# ('first', 'minut'):0.07142857142857142
# ('minut', 'mayb'):0.2
# ('mayb', 'i'):0.1111111111111111
# ('no', 'sensibl'):0.0196078431372549
# ('sensibl', 'at'):1.0
# ('all', 'to'):0.013333333333333334
# ('to', 'feel'):0.00911854103343465
# ('feel', 'ani'):0.02564102564102564
# ('ani', 'empti'):0.047619047619047616
# ('empti', 'with'):0.25
# ('thi', 'joke'):0.008733624454148471
# ('is', 'annoy'):0.006666666666666667
# ('annoy', 'the'):0.6666666666666666
# ('the', 'screenplay'):0.0027816411682892906
# ('screenplay', 'is'):0.16666666666666666
# ('music', 'is'):0.14285714285714285
# ('more', 'nois'):0.0196078431372549
# ('nois', 'than'):1.0
# ('than', 'music'):0.03333333333333333
# ('music', 'one'):0.14285714285714285
# ('the', 'worst'):0.004172461752433936
# ('worst', 'move'):0.5
# ('move', 'i'):0.10256410256410256
# ('last', 'year'):0.14285714285714285
# ('dont', 'save'):0.03225806451612903
# ('save', 'neither'):0.5
# ('neither', 'phoenix'):1.0
# ('phoenix', 'i'):0.016129032258064516
# ('never', 'like'):0.07692307692307693
# ('like', 'him'):0.016129032258064516
# ('him', 'but'):0.043478260869565216
# ('way', 'he'):0.030303030303030304
# ('he', 'laugh'):0.03896103896103896
# ('is', 'absolut'):0.006666666666666667
# ('absolut', 'aw'):0.2857142857142857
# ('aw', 'and'):0.25
# ('laugh', 'for'):0.10526315789473684
# ('so', 'import'):0.014084507042253521
# ('import', 'take'):0.16666666666666666
# ('watch', 'to'):0.022222222222222223
# ('to', 'gothic'):0.00303951367781155
# ('see', 'the'):0.13333333333333333
# ('joke', 'even'):0.006211180124223602
# ('even', 'better'):0.03225806451612903
# ('than', 'jack'):0.03333333333333333
# ('nicholson', 'and'):0.3333333333333333
# ('and', 'heath'):0.0023923444976076554
# ('ledger', 'mile'):0.05
# ('away', 'from'):0.14285714285714285
# ('from', 'thi'):0.020833333333333332
# ('thi', 'rubbish'):0.004366812227074236
# ('rubbish', 'thi'):1.0
# ('masterpiec', 'it'):0.1
# ('it', 'absolut'):0.0026246719160104987
# ('absolut', 'epitom'):0.14285714285714285
# ('epitom', 'what'):1.0
# ('a', 'do'):0.006072874493927126
# ('do', 'movi'):0.046511627906976744
# ('be', 'dark'):0.008547008547008548
# ('dark', 'emot'):0.03571428571428571
# ('emot', 'thought'):0.1111111111111111
# ('thought', 'provok'):0.07142857142857142
# ('provok', 'not'):1.0
# ('not', 'just'):0.030927835051546393
# ('just', 'action'):0.016129032258064516
# ('action', 'action'):0.11764705882352941
# ('action', 'one'):0.058823529411764705
# ('move', 'give'):0.05128205128205128
# ('time', 'critic'):0.024390243902439025
# ('critic', 'have'):0.125
# ('have', 'definit'):0.013888888888888888
# ('definit', 'lost'):0.07692307692307693
# ('lost', 'touch'):0.3333333333333333
# ('touch', 'with'):0.25
# ('the', 'public'):0.0013908205841446453
# ('public', 'and'):0.5
# ('and', 'should'):0.0023923444976076554
# ('be', 'ignor'):0.008547008547008548
# ('ignor', 'on'):0.2
# ('one', 'do'):0.0196078431372549
# ('do', 'yourself'):0.046511627906976744
# ('yourself', 'a'):0.5
# ('a', 'favor'):0.004048582995951417
# ('favor', 'and'):1.0
# ('and', 'watch'):0.0023923444976076554
# ('and', 'rememb'):0.0023923444976076554
# ('rememb', 'to'):0.25
# ('be', 'good'):0.008547008547008548
# ('good', 'to'):0.03636363636363636
# ('to', 'one'):0.00303951367781155
# ('anoth', 'you'):0.14285714285714285
# ('what', 'someon'):0.018518518518518517
# ('someon', 'el'):0.25
# ('el', 'is'):0.3333333333333333
# ('through', 'there'):0.07692307692307693
# ('a', 'reason'):0.0020242914979757085
# ('whi', 'thi'):0.05
# ('masterpiec', 'is'):0.05
# ('be', 'plan'):0.008547008547008548
# ('plan', 'by'):0.3333333333333333
# ('the', 'croni'):0.0013908205841446453
# ('croni', 'capitalist'):1.0
# ('capitalist', 'critic'):1.0
# ('critic', 'it'):0.125
# ('it', 'challeng'):0.0026246719160104987
# ('challeng', 'their'):0.3333333333333333
# ('their', 'all'):0.0625
# ('all', 'too'):0.013333333333333334
# ('too', 'comfort'):0.05555555555555555
# ('comfort', 'face'):0.5
# ('face', 'construct'):0.16666666666666666
# ('construct', 'of'):1.0
# ('of', 'realiti'):0.003424657534246575
# ('realiti', 'and'):0.2
# ('it', 'doe'):0.005249343832020997
# ('doe', 'so'):0.058823529411764705
# ('so', 'in'):0.014084507042253521
# ('in', 'such'):0.005555555555555556
# ('an', 'effect'):0.018518518518518517
# ('effect', 'way'):0.3333333333333333
# ('it', 'almost'):0.0026246719160104987
# ('almost', 'automat'):0.1
# ('automat', 'elicit'):1.0
# ('elicit', 'a'):1.0
# ('a', 'dishonest'):0.0020242914979757085
# ('dishonest', 'kneejerk'):1.0
# ('kneejerk', 'defens'):1.0
# ('defens', 'reaction'):1.0
# ('reaction', 'from'):0.5
# ('from', 'them'):0.020833333333333332
# ('them', 'frighten'):0.06666666666666667
# ('frighten', 'to'):1.0
# ('the', 'bone'):0.0027816411682892906
# ('bone', 'that'):0.25
# ('that', 'their'):0.00510204081632653
# ('their', 'alight'):0.0625
# ('alight', 'charg'):1.0
# ('charg', 'might'):0.5
# ('might', 'get'):0.14285714285714285
# ('get', 'uncov'):0.03225806451612903
# ('uncov', 'it'):1.0
# ('not', 'joke'):0.010309278350515464
# ('is', 'delus'):0.0033333333333333335
# ('delus', 'it'):0.5
# ('is', 'they'):0.0033333333333333335
# ('they', 'that'):0.03225806451612903
# ('that', 'sell'):0.00510204081632653
# ('sell', 'delus'):1.0
# ('delus', 'in'):0.5
# ('in', 'order'):0.005555555555555556
# ('order', 'to'):0.5
# ('to', 'maintain'):0.00303951367781155
# ('maintain', 'the'):1.0
# ('the', 'statu'):0.0013908205841446453
# ('statu', 'que'):0.5
# ('que', 'but'):1.0
# ('but', 'eventu'):0.007874015748031496
# ('eventu', 'and'):1.0
# ('they', 'know'):0.03225806451612903
# ('you', 'get'):0.01020408163265306
# ('get', 'what'):0.03225806451612903
# ('what', 'you'):0.018518518518518517
# ('you', 'deserv'):0.01020408163265306
# ('deserv', 'that'):0.09090909090909091
# ('that', 'sentenc'):0.00510204081632653
# ('sentenc', 'and'):1.0
# ('that', 'sentiment'):0.00510204081632653
# ('sentiment', 'is'):1.0
# ('what', 'so'):0.037037037037037035
# ('so', 'scar'):0.014084507042253521
# ('scar', 'them'):0.14285714285714285
# ('them', 'becaus'):0.06666666666666667
# ('movi', 'cut'):0.004310344827586207
# ('cut', 'too'):0.3333333333333333
# ('too', 'close'):0.05555555555555555
# ('and', 'like'):0.0023923444976076554
# ('like', 'all'):0.016129032258064516
# ('all', 'great'):0.013333333333333334
# ('great', 'gamechang'):0.034482758620689655
# ('gamechang', 'art'):1.0
# ('art', 'it'):0.2857142857142857
# ('bit', 'too'):0.125
# ('too', 'true'):0.05555555555555555
# ('true', 'when'):0.125
# ('when', 'joke'):0.038461538461538464
# ('joke', 'who'):0.006211180124223602
# ('who', 'is'):0.07142857142857142
# ('true', 'hero'):0.125
# ('hero', 'here'):0.16666666666666666
# ('here', 'help'):0.07692307692307693
# ('help', 'a'):0.2
# ('charact', 'equal'):0.01639344262295082
# ('equal', 'mistreat'):0.3333333333333333
# ('mistreat', 'by'):0.5
# ('the', 'power'):0.0013908205841446453
# ('power', 'that'):0.16666666666666666
# ('be', 'go'):0.008547008547008548
# ('go', 'free'):0.041666666666666664
# ('free', 'he'):0.5
# ('he', 'point'):0.012987012987012988
# ('point', 'that'):0.05
# ('onli', 'one'):0.037037037037037035
# ('one', 'that'):0.0196078431372549
# ('that', 'treat'):0.00510204081632653
# ('treat', 'him'):0.25
# ('him', 'well'):0.043478260869565216
# ('well', 'thi'):0.07692307692307693
# ('a', 'call'):0.0020242914979757085
# ('for', 'kind'):0.008403361344537815
# ('kind', 'that'):0.1111111111111111
# ('is', 'essenc'):0.0033333333333333335
# ('essenc', 'of'):0.5
# ('is', 'bare'):0.0033333333333333335
# ('bare', 'notic'):0.5
# ('notic', 'by'):0.5
# ('by', 'those'):0.018518518518518517
# ('who', 'like'):0.03571428571428571
# ('movi', 'thoma'):0.004310344827586207
# ('thoma', 'wayn'):1.0
# ('wayn', 'think'):0.5
# ('all', 'despic'):0.013333333333333334
# ('despic', 'clown'):1.0
# ('clown', 'so'):0.08333333333333333
# ('so', 'they'):0.014084507042253521
# ('they', 'lie'):0.03225806451612903
# ('lie', 'and'):0.5
# ('and', 'pool'):0.0023923444976076554
# ('pool', 'wool'):0.3333333333333333
# ('wool', 'over'):1.0
# ('over', 'our'):0.07142857142857142
# ('our', 'eye'):0.1111111111111111
# ('eye', 'a'):0.6666666666666666
# ('they', 'onli'):0.03225806451612903
# ('onli', 'can'):0.037037037037037035
# ('can', 'misconstru'):0.024390243902439025
# ('misconstru', 'and'):1.0
# ('make', 'fals'):0.025
# ('fals', 'scar'):1.0
# ('scar', 'so'):0.14285714285714285
# ('so', 'that'):0.014084507042253521
# ('most', 'damag'):0.04
# ('damag', 'for'):1.0
# ('for', 'them'):0.008403361344537815
# ('them', 'would'):0.06666666666666667
# ('not', 'get'):0.010309278350515464
# ('get', 'across'):0.03225806451612903
# ('across', 'all'):1.0
# ('these', 'are'):0.14285714285714285
# ('are', 'mark'):0.015873015873015872
# ('in', 'europ'):0.005555555555555556
# ('europ', 'it'):1.0
# ('wa', 'instantli'):0.0070921985815602835
# ('instantli', 'recogn'):1.0
# ('recogn', 'and'):1.0
# ('and', 'reward'):0.0023923444976076554
# ('reward', 'for'):1.0
# ('the', 'subvers'):0.0013908205841446453
# ('subvers', 'potenti'):1.0
# ('potenti', 'it'):0.2
# ('ha', 'in'):0.030303030303030304
# ('in', 'north'):0.005555555555555556
# ('north', 'america'):1.0
# ('america', 'it'):1.0
# ('it', 'scare'):0.0026246719160104987
# ('scare', 'the'):1.0
# ('hell', 'out'):0.3333333333333333
# ('of', 'conformist'):0.003424657534246575
# ('conformist', 'and'):1.0
# ('the', 'reaction'):0.0013908205841446453
# ('reaction', 'wa'):0.5
# ('wa', 'for'):0.014184397163120567
# ('mani', 'an'):0.03225806451612903
# ('an', 'almost'):0.018518518518518517
# ('almost', 'reflex'):0.1
# ('reflex', 'reject'):1.0
# ('reject', 'which'):0.5
# ('which', 'mean'):0.038461538461538464
# ('mean', 'it'):0.1111111111111111
# ('it', 'hit'):0.005249343832020997
# ('hit', 'it'):0.2
# ('hit', 'hard'):0.2
# ('hard', 'quit'):0.14285714285714285
# ('quit', 'uncomfort'):0.09090909090909091
# ('uncomfort', 'so'):0.25
# ('so', 'and'):0.014084507042253521
# ('if', 'anyth'):0.03636363636363636
# ('anyth', 'the'):0.09090909090909091
# ('hope', 'cri'):0.045454545454545456
# ('cri', 'hate'):0.2
# ('hate', 'so'):0.14285714285714285
# ('much', 'it'):0.03571428571428571
# ('that', 'expo'):0.00510204081632653
# ('expo', 'them'):0.5
# ('them', 'and'):0.06666666666666667
# ('and', 'even'):0.004784688995215311
# ('even', 'more'):0.06451612903225806
# ('so', 'expo'):0.014084507042253521
# ('expo', 'the'):0.5
# ('the', 'paper'):0.0013908205841446453
# ('paper', 'tiger'):1.0
# ('tiger', 'of'):1.0
# ('the', 'blood'):0.0013908205841446453
# ('blood', 'suck'):1.0
# ('suck', 'system'):0.3333333333333333
# ('system', 'they'):0.5
# ('they', 'depend'):0.03225806451612903
# ('depend', 'on'):1.0
# ('on', 'for'):0.014084507042253521
# ('for', 'what'):0.008403361344537815
# ('is', 'creativ'):0.0033333333333333335
# ('creativ', 'actor'):0.25
# ('actor', 'joaquin'):0.1111111111111111
# ('joaquin', 'creativ'):0.01818181818181818
# ('creativ', 'embodi'):0.25
# ('embodi', 'the'):0.6666666666666666
# ('role', 'of'):0.3333333333333333
# ('joke', 'film'):0.012422360248447204
# ('film', 'deserv'):0.011627906976744186
# ('deserv', 'more'):0.09090909090909091
# ('than', '10'):0.03333333333333333
# ('10', 'writerdirector'):0.3333333333333333
# ('writerdirector', 'told'):1.0
# ('phillip', 'new'):0.1
# ('new', 'movi'):0.14285714285714285
# ('movi', 'joke'):0.004310344827586207
# ('joke', 'appeal'):0.006211180124223602
# ('appeal', 'to'):1.0
# ('me', 'on'):0.02857142857142857
# ('on', 'multipl'):0.014084507042253521
# ('multipl', 'level'):0.2
# ('level', 'primarili'):0.3333333333333333
# ('primarili', 'by'):1.0
# ('by', 'offer'):0.018518518518518517
# ('offer', 'an'):0.3333333333333333
# ('an', 'engag'):0.018518518518518517
# ('engag', 'stori'):0.2
# ('stori', 'strongli'):0.02857142857142857
# ('strongli', 'root'):1.0
# ('root', 'in'):0.25
# ('in', 'believ'):0.005555555555555556
# ('believ', 'realiti'):0.07142857142857142
# ('realiti', 'relat'):0.2
# ('to', 'audienc'):0.00303951367781155
# ('audienc', 'mainli'):0.2
# ('mainli', 'by'):1.0
# ('by', 'oppos'):0.018518518518518517
# ('oppos', 'protagonist'):1.0
# ('protagonist', 'preval'):1.0
# ('preval', 'dark'):1.0
# ('dark', 'depress'):0.03571428571428571
# ('depress', 'mood'):0.2
# ('mood', 'while'):1.0
# ('while', 'use'):0.06666666666666667
# ('use', 'often'):0.2
# ('often', 'optimist'):0.5
# ('optimist', 'soundtrack'):1.0
# ('soundtrack', 'and'):0.25
# ('and', 'sound'):0.0023923444976076554
# ('sound', 'edit'):0.3333333333333333
# ('edit', 'shallow'):0.3333333333333333
# ('shallow', 'nonetheless'):0.5
# ('nonetheless', 'rich'):1.0
# ('rich', 'visual'):0.3333333333333333
# ('visual', 'angl'):0.5
# ('angl', 'and'):0.25
# ('and', 'frame'):0.0023923444976076554
# ('frame', 'theatric'):0.5
# ('theatric', 'augment'):0.5
# ('augment', 'through'):1.0
# ('through', 'express'):0.07692307692307693
# ('express', 'costum'):0.3333333333333333
# ('costum', 'drop'):0.3333333333333333
# ('drop', 'and'):0.3333333333333333
# ('and', 'set'):0.0023923444976076554
# ('set', 'but'):0.14285714285714285
# ('but', 'most'):0.007874015748031496
# ('most', 'impress'):0.04
# ('impress', 'via'):0.3333333333333333
# ('via', 'great'):1.0
# ('great', 'princip'):0.034482758620689655
# ('princip', 'perform'):1.0
# ('and', 'act'):0.004784688995215311
# ('act', 'choic'):0.023255813953488372
# ('phoenix', 'in'):0.016129032258064516
# ('the', 'lead'):0.0013908205841446453
# ('lead', 'a'):0.3333333333333333
# ('a', 'titl'):0.0020242914979757085
# ('titl', 'charact'):0.2
# ('charact', 'under'):0.01639344262295082
# ('under', 'proper'):0.5
# ('proper', 'section'):0.16666666666666666
# ('section', 'name'):1.0
# ('name', 'arthur'):0.25
# ('fleck', 'whose'):0.3333333333333333
# ('whose', 'sudden'):0.5
# ('sudden', 'uncontrol'):1.0
# ('uncontrol', 'and'):1.0
# ('and', 'seemingli'):0.0023923444976076554
# ('seemingli', 'inappropri'):1.0
# ('inappropri', 'laughter'):0.5
# ('laughter', 'justifi'):1.0
# ('a', 'medic'):0.0020242914979757085
# ('medic', 'condit'):1.0
# ('condit', 'easili'):0.3333333333333333
# ('easili', 'counterpoint'):0.25
# ('counterpoint', 'the'):1.0
# ('the', 'pain'):0.0013908205841446453
# ('pain', 'need'):0.16666666666666666
# ('need', 'for'):0.05555555555555555
# ('for', 'outcri'):0.008403361344537815
# ('outcri', 'from'):1.0
# ('from', 'gothic'):0.020833333333333332
# ('gothic', 'read'):0.2
# ('read', 'ani'):0.3333333333333333
# ('ani', 'citi'):0.047619047619047616
# ('citi', 'mass'):1.0
# ('mass', 'hurt'):0.25
# ('hurt', 'and'):1.0
# ('and', 'depriv'):0.0023923444976076554
# ('depriv', 'by'):1.0
# ('by', 'injustic'):0.018518518518518517
# ('injustic', 'of'):0.5
# ('their', 'quotidian'):0.0625
# ('quotidian', 'exist'):1.0
# ('exist', 'a'):0.25
# ('a', 'well'):0.006072874493927126
# ('well', 'a'):0.15384615384615385
# ('a', 'by'):0.0020242914979757085
# ('by', 'robert'):0.018518518518518517
# ('robert', 'de'):1.0
# ('no', 'in'):0.0392156862745098
# ('a', 'quintessenti'):0.0020242914979757085
# ('quintessenti', 'support'):1.0
# ('support', 'role'):0.3333333333333333
# ('a', 'comedi'):0.0020242914979757085
# ('comedi', 'show'):0.16666666666666666
# ('show', 'host'):0.058823529411764705
# ('host', 'murray'):1.0
# ('murray', 'franklin'):0.5
# ('franklin', 'both'):1.0
# ('both', 'worthi'):0.16666666666666666
# ('the', 'endoftheyear'):0.0013908205841446453
# ('endoftheyear', 'act'):1.0
# ('act', 'award'):0.023255813953488372
# ('award', 'consider'):0.3333333333333333
# ('consider', 'and'):1.0
# ('and', 'by'):0.0023923444976076554
# ('by', 'set'):0.018518518518518517
# ('set', 'believ'):0.14285714285714285
# ('believ', 'recours'):0.07142857142857142
# ('recours', 'for'):1.0
# ('the', 'futur'):0.0027816411682892906
# ('futur', 'adventur'):0.25
# ('adventur', 'of'):1.0
# ('most', 'realist'):0.04
# ('realist', 'do'):0.125
# ('comic', 'charact'):0.043478260869565216
# ('charact', 'the'):0.03278688524590164
# ('batman', 'not'):0.05263157894736842
# ('superhero', 'at'):0.09090909090909091
# ('all', 'with'):0.013333333333333334
# ('with', 'hi'):0.06818181818181818
# ('hi', 'extraordinari'):0.02
# ('extraordinari', 'capabl'):0.5
# ('capabl', 'rather'):1.0
# ('rather', 'result'):0.3333333333333333
# ('result', 'from'):1.0
# ('from', 'hi'):0.041666666666666664
# ('hi', 'physic'):0.02
# ('physic', 'fit'):0.25
# ('fit', 'and'):1.0
# ('and', 'skill'):0.0023923444976076554
# ('skill', 'combin'):1.0
# ('combin', 'with'):0.5
# ('high', 'technolog'):0.07692307692307693
# ('technolog', 'employ'):1.0
# ('employ', 'who'):1.0
# ('who', 'appear'):0.03571428571428571
# ('appear', 'here'):0.5
# ('here', 'onli'):0.07692307692307693
# ('onli', 'a'):0.07407407407407407
# ('a', 'young'):0.0020242914979757085
# ('young', 'boy'):1.0
# ('boy', 'and'):0.25
# ('and', 'whose'):0.0023923444976076554
# ('whose', 'later'):0.5
# ('later', 'adult'):0.3333333333333333
# ('adult', 'activ'):0.3333333333333333
# ('activ', 'could'):1.0
# ('be', 'understood'):0.008547008547008548
# ('understood', 'a'):0.5
# ('a', 'larg'):0.0020242914979757085
# ('larg', 'driven'):1.0
# ('driven', 'by'):1.0
# ('what', 'ha'):0.018518518518518517
# ('ha', 'happen'):0.030303030303030304
# ('happen', 'to'):0.16666666666666666
# ('hi', 'parent'):0.02
# ('parent', 'in'):1.0
# ('final', 'scene'):0.16666666666666666
# ('scene', 'of'):0.1111111111111111
# ('event', 'directli'):0.5
# ('directli', 'inspir'):0.5
# ('inspir', 'by'):0.3333333333333333
# ('by', 'action'):0.018518518518518517
# ('action', 'of'):0.11764705882352941
# ('joke', 'henceforth'):0.006211180124223602
# ('henceforth', 'hi'):1.0
# ('hi', 'futur'):0.02
# ('futur', 'main'):0.25
# ('main', 'nemes'):0.125
# ('nemes', 'in'):1.0
# ('make', 'sure'):0.025
# ('sure', 'to'):0.08333333333333333
# ('movi', '1'):0.004310344827586207
# ('1', 'star'):0.75
# ('star', 'becaus'):0.125
# ('definit', 'not'):0.07692307692307693
# ('a', '89'):0.0020242914979757085
# ('89', 'that'):1.0
# ('a', 'lie'):0.0020242914979757085
# ('lie', 'joke'):0.5
# ('amaz', 'movi'):0.07692307692307693
# ('it', 'far'):0.0026246719160104987
# ('from', 'great'):0.020833333333333332
# ('great', 'more'):0.034482758620689655
# ('more', 'to'):0.0196078431372549
# ('the', 'bore'):0.0013908205841446453
# ('bore', 'side'):0.05
# ('side', 'it'):0.3333333333333333
# ('it', 'lack'):0.0026246719160104987
# ('lack', 'plot'):0.125
# ('twist', 'and'):0.3333333333333333
# ('and', 'focu'):0.0023923444976076554
# ('focu', 'too'):1.0
# ('too', 'much'):0.1111111111111111
# ('much', 'on'):0.03571428571428571
# ('on', 'charact'):0.014084507042253521
# ('develop', 'how'):0.16666666666666666
# ('how', 'mani'):0.03333333333333333
# ('time', 'someon'):0.024390243902439025
# ('someon', 'need'):0.25
# ('get', 'punch'):0.03225806451612903
# ('punch', 'in'):1.0
# ('the', 'face'):0.0013908205841446453
# ('face', 'befor'):0.16666666666666666
# ('befor', 'they'):0.08333333333333333
# ('go', 'crazi'):0.08333333333333333
# ('crazi', 'he'):0.125
# ('he', 'suffer'):0.012987012987012988
# ('suffer', 'get'):0.14285714285714285
# ('get', 'fire'):0.03225806451612903
# ('fire', 'ha'):1.0
# ('ill', 'nobodi'):0.037037037037037035
# ('nobodi', 'love'):0.3333333333333333
# ('love', 'him'):0.1
# ('him', 'he'):0.043478260869565216
# ('he', 'sad'):0.012987012987012988
# ('sad', 'and'):0.2
# ('he', 'cri'):0.025974025974025976
# ('cri', 'and'):0.4
# ('laugh', 'again'):0.05263157894736842
# ('again', 'and'):0.2
# ('he', 'kill'):0.012987012987012988
# ('kill', 'some'):0.125
# ('peopl', 'and'):0.0425531914893617
# ('it', 'that'):0.007874015748031496
# ('movi', 'do'):0.004310344827586207
# ('do', 'can'):0.023255813953488372
# ('can', 'still'):0.024390243902439025
# ('still', 'give'):0.2
# ('give', 'u'):0.1
# ('u', 'a'):0.13333333333333333
# ('a', 'compel'):0.0020242914979757085
# ('compel', 'movi'):0.3333333333333333
# ('movi', 'want'):0.004310344827586207
# ('want', 'quit'):0.03225806451612903
# ('hope', 'about'):0.09090909090909091
# ('mean', 'an'):0.1111111111111111
# ('stori', 'of'):0.02857142857142857
# ('a', 'villain'):0.0020242914979757085
# ('villain', 'made'):0.07142857142857142
# ('director', 'of'):0.25
# ('of', 'hanov'):0.003424657534246575
# ('hanov', 'move'):0.5
# ('move', 'what'):0.02564102564102564
# ('what', 'could'):0.037037037037037035
# ('could', 'i'):0.04
# ('i', 'even'):0.004405286343612335
# ('even', 'expect'):0.03225806451612903
# ('expect', 'then'):0.058823529411764705
# ('review', 'start'):0.04
# ('to', 'drop'):0.00303951367781155
# ('drop', 'still'):0.3333333333333333
# ('still', 'want'):0.2
# ('want', 'sure'):0.06451612903225806
# ('sure', 'if'):0.08333333333333333
# ('would', 'like'):0.03225806451612903
# ('and', 'after'):0.007177033492822967
# ('after', 'i'):0.2
# ('saw', 'it'):0.3333333333333333
# ('wa', 'way'):0.0070921985815602835
# ('way', 'better'):0.06060606060606061
# ('than', 'i'):0.03333333333333333
# ('be', 'i'):0.017094017094017096
# ('wont', 'call'):0.2
# ('call', 'it'):0.18181818181818182
# ('masterpiec', 'but'):0.1
# ('definit', 'is'):0.07692307692307693
# ('is', 'on'):0.0033333333333333335
# ('on', 'my'):0.028169014084507043
# ('my', 'top'):0.030303030303030304
# ('top', '3'):0.3333333333333333
# ('3', 'do'):0.2
# ('do', 'film'):0.046511627906976744
# ('all', 'time'):0.013333333333333334
# ('time', 'good'):0.024390243902439025
# ('good', 'there'):0.03636363636363636
# ('there', 'hardli'):0.02127659574468085
# ('hardli', 'anyth'):1.0
# ('anyth', 'bad'):0.09090909090909091
# ('bad', 'about'):0.05263157894736842
# ('great', 'job'):0.034482758620689655
# ('job', 'of'):0.3333333333333333
# ('of', 'bring'):0.003424657534246575
# ('bring', 'the'):0.16666666666666666
# ('charact', 'into'):0.01639344262295082
# ('into', 'life'):0.043478260869565216
# ('life', 'rather'):0.05555555555555555
# ('rather', 'than'):0.6666666666666666
# ('typic', 'superherosupervillain'):0.25
# ('superherosupervillain', 'origin'):1.0
# ('stori', 'we'):0.02857142857142857
# ('we', 'get'):0.025
# ('a', 'psycholog'):0.0020242914979757085
# ('psycholog', 'drama'):0.125
# ('drama', 'horror'):0.16666666666666666
# ('horror', 'and'):0.25
# ('and', 'thank'):0.0023923444976076554
# ('thank', 'god'):1.0
# ('god', 'we'):0.5
# ('got', 'that'):0.125
# ('gene', 'i'):0.16666666666666666
# ('love', 'film'):0.1
# ('film', 'like'):0.023255813953488372
# ('like', 'infin'):0.016129032258064516
# ('infin', 'war'):1.0
# ('war', 'day'):1.0
# ('day', 'of'):0.25
# ('of', 'futur'):0.003424657534246575
# ('futur', 'past'):0.25
# ('past', 'engag'):0.16666666666666666
# ('engag', 'and'):0.2
# ('and', 'aim'):0.0023923444976076554
# ('aim', 'spiderman'):1.0
# ('spiderman', 'but'):1.0
# ('but', 'occasion'):0.007874015748031496
# ('occasion', 'it'):1.0
# ('to', 'take'):0.0060790273556231
# ('a', 'break'):0.0020242914979757085
# ('break', 'from'):0.25
# ('from', 'such'):0.020833333333333332
# ('such', 'film'):0.14285714285714285
# ('film', 'it'):0.046511627906976744
# ('it', 'kind'):0.005249343832020997
# ('kind', 'of'):0.6666666666666666
# ('of', 'in'):0.003424657534246575
# ('the', 'categori'):0.0013908205841446453
# ('categori', 'of'):0.3333333333333333
# ('of', 'film'):0.003424657534246575
# ('like', 'unbreak'):0.016129032258064516
# ('unbreak', 'basic'):1.0
# ('basic', 'the'):1.0
# ('no', 'soiler'):0.0392156862745098
# ('soiler', 'ahead'):0.3333333333333333
# ('ahead', 'arthur'):1.0
# ('arthur', 'be'):0.05555555555555555
# ('be', 'torment'):0.008547008547008548
# ('torment', 'by'):0.5
# ('the', 'societi'):0.0027816411682892906
# ('and', 'be'):0.0023923444976076554
# ('unstabl', 'longer'):0.3333333333333333
# ('longer', 'lose'):0.3333333333333333
# ('lose', 'hi'):0.5
# ('hi', 'mind'):0.04
# ('mind', 'after'):0.2
# ('after', 'the'):0.1
# ('the', 'constant'):0.0013908205841446453
# ('constant', 'torment'):1.0
# ('torment', 'and'):0.5
# ('after', 'that'):0.2
# ('that', 'all'):0.01020408163265306
# ('all', 'hell'):0.013333333333333334
# ('hell', 'break'):0.3333333333333333
# ('break', 'loo'):0.25
# ('loo', 'that'):0.5
# ('show', 'it'):0.058823529411764705
# ('be', 'quit'):0.008547008547008548
# ('quit', 'difficult'):0.09090909090909091
# ('difficult', 'to'):0.6666666666666666
# ('stori', 'for'):0.05714285714285714
# ('a', 'plot'):0.0020242914979757085
# ('plot', 'like'):0.05
# ('thi', 'sinc'):0.004366812227074236
# ('sinc', 'there'):0.3333333333333333
# ('are', 'mani'):0.015873015873015872
# ('move', 'with'):0.02564102564102564
# ('thi', 'kind'):0.004366812227074236
# ('of', 'plot'):0.003424657534246575
# ('plot', 'aw'):0.05
# ('aw', 'happi'):0.25
# ('happi', 'one'):0.2
# ('one', 'includ'):0.0196078431372549
# ('includ', 'i'):1.0
# ('i', 'complet'):0.004405286343612335
# ('complet', 'like'):0.07142857142857142
# ('movi', 'mean'):0.004310344827586207
# ('mean', 'the'):0.1111111111111111
# ('screenplay', 'and'):0.16666666666666666
# ('direct', 'work'):0.0625
# ('work', 'for'):0.25
# ('me', 'you'):0.02857142857142857
# ('can', 'feel'):0.04878048780487805
# ('arthur', 'whenev'):0.05555555555555555
# ('whenev', 'the'):0.5
# ('movi', 'ask'):0.004310344827586207
# ('ask', 'you'):0.25
# ('you', 'to'):0.02040816326530612
# ('you', 'want'):0.02040816326530612
# ('to', 'root'):0.00303951367781155
# ('root', 'for'):0.25
# ('arthur', 'but'):0.05555555555555555
# ('but', 'you'):0.015748031496062992
# ('you', 'know'):0.01020408163265306
# ('will', 'mean'):0.02564102564102564
# ('mean', 'some'):0.1111111111111111
# ('some', 'incred'):0.03225806451612903
# ('incred', 'terribl'):0.14285714285714285
# ('terribl', 'thing'):0.16666666666666666
# ('thing', 'will'):0.05
# ('will', 'happen'):0.02564102564102564
# ('happen', 'we'):0.05555555555555555
# ('him', 'slowli'):0.043478260869565216
# ('slowli', 'transit'):0.3333333333333333
# ('transit', 'into'):0.3333333333333333
# ('into', 'joke'):0.08695652173913043
# ('he', 'complet'):0.012987012987012988
# ('complet', 'turn'):0.07142857142857142
# ('turn', 'into'):0.25
# ('joke', 'it'):0.024844720496894408
# ('is', 'worth'):0.006666666666666667
# ('worth', 'a'):0.2857142857142857
# ('a', 'round'):0.0020242914979757085
# ('round', 'of'):1.0
# ('of', 'applaus'):0.003424657534246575
# ('applaus', 'we'):0.3333333333333333
# ('feel', 'good'):0.02564102564102564
# ('a', 'terrifi'):0.0020242914979757085
# ('terrifi', 'with'):0.5
# ('the', 'action'):0.0013908205841446453
# ('joke', 'whenev'):0.006211180124223602
# ('whenev', 'he'):0.5
# ('he', 'snap'):0.012987012987012988
# ('snap', 'and'):0.5
# ('and', 'crazi'):0.0023923444976076554
# ('crazi', 'stuff'):0.125
# ('stuff', 'happen'):1.0
# ('happen', 'without'):0.05555555555555555
# ('without', 'get'):0.07692307692307693
# ('get', 'into'):0.03225806451612903
# ('into', 'soiler'):0.043478260869565216
# ('soiler', 'i'):0.3333333333333333
# ('would', 'say'):0.03225806451612903
# ('say', 'in'):0.027777777777777776
# ('in', 'short'):0.011111111111111112
# ('short', 'that'):0.14285714285714285
# ('ha', 'mani'):0.030303030303030304
# ('mani', 'suitabl'):0.03225806451612903
# ('suitabl', 'line'):0.3333333333333333
# ('line', 'and'):0.3333333333333333
# ('and', 'each'):0.0023923444976076554
# ('each', 'of'):0.16666666666666666
# ('them', 'make'):0.06666666666666667
# ('make', 'sen'):0.025
# ('sen', 'whatev'):0.3333333333333333
# ('whatev', 'joke'):0.5
# ('a', 'psychopath'):0.004048582995951417
# ('psychopath', 'say'):0.3333333333333333
# ('say', 'is'):0.027777777777777776
# ('realist', 'than'):0.125
# ('than', 'what'):0.03333333333333333
# ('a', 'sane'):0.0020242914979757085
# ('sane', 'person'):1.0
# ('person', 'say'):0.05
# ('say', 'and'):0.027777777777777776
# ('and', 'obvious'):0.0023923444976076554
# ('obvious', 'ha'):1.0
# ('some', 'sick'):0.03225806451612903
# ('sick', 'terrifi'):0.5
# ('terrifi', 'and'):0.5
# ('and', 'gruesom'):0.0023923444976076554
# ('gruesom', 'joke'):1.0
# ('joke', 'moment'):0.012422360248447204
# ('proper', 'joke'):0.16666666666666666
# ('have', 'if'):0.013888888888888888
# ('not', 'clear'):0.010309278350515464
# ('clear', 'by'):0.25
# ('trailer', 'there'):0.125
# ('no', 'batman'):0.0196078431372549
# ('batman', 'here'):0.05263157894736842
# ('here', 'but'):0.07692307692307693
# ('but', 'again'):0.007874015748031496
# ('again', 'no'):0.2
# ...
# ('their', 'childhood'):0.0625
# ('childhood', 'mock'):0.5
# ('mock', 'in'):1.0
# ('in', 'adolesc'):0.005555555555555556
# ('adolesc', 'misunderstood'):1.0
# ('misunderstood', 'in'):0.3333333333333333
# ('in', 'adulthood'):0.005555555555555556
# ('adulthood', 'without'):1.0
# ('without', 'ever'):0.07692307692307693
# ('ever', 'have'):0.0625
# ('have', 'anyon'):0.013888888888888888
# ('anyon', 'to'):0.125
# ('to', 'help'):0.00303951367781155
# ('help', 'them'):0.2
# ('them', 'effect'):0.06666666666666667
# ('effect', 'but'):0.3333333333333333
# ('but', 'no'):0.007874015748031496
# ('no', 'the'):0.0196078431372549
# ('the', 'vast'):0.0013908205841446453
# ('vast', 'major'):0.5
# ('major', 'of'):1.0
# ('them', 'were'):0.06666666666666667
# ('were', 'born'):0.045454545454545456
# ('born', 'with'):1.0
# ('a', 'miss'):0.0020242914979757085
# ('miss', 'bolt'):0.14285714285714285
# ('bolt', 'in'):1.0
# ('their', 'head'):0.0625
# ('head', 'someth'):1.0
# ('someth', 'wa'):0.08333333333333333
# ('wa', 'wrong'):0.0070921985815602835
# ('wrong', 'in'):0.1
# ('in', 'them'):0.005555555555555556
# ('them', 'from'):0.06666666666666667
# ('the', 'start'):0.0013908205841446453
# ('start', 'here'):0.09090909090909091
# ('director', 'want'):0.125
# ('make', 'u'):0.025
# ('u', 'cri'):0.06666666666666667
# ('cri', 'by'):0.2
# ('by', 'portray'):0.018518518518518517
# ('portray', 'roughli'):0.09090909090909091
# ('roughli', 'the'):1.0
# ('most', 'cartoon'):0.04
# ('cartoon', 'miseri'):1.0
# ('miseri', 'everyth'):0.5
# ('in', 'bold'):0.005555555555555556
# ('bold', 'capit'):1.0
# ('capit', 'letter'):1.0
# ('letter', 'undermin'):1.0
# ('undermin', 'and'):0.5
# ('and', 'highlight'):0.0023923444976076554
# ('highlight', 'to'):0.5
# ('be', 'sure'):0.008547008547008548
# ('sure', 'that'):0.08333333333333333
# ('that', 'we'):0.01020408163265306
# ('we', 'fulli'):0.025
# ('fulli', 'understood'):0.5
# ('understood', 'that'):0.5
# ('charact', 'didn'):0.01639344262295082
# ('didn', 'have'):0.1
# ('have', 'an'):0.013888888888888888
# ('easi', 'life'):0.2
# ('that', 'our'):0.00510204081632653
# ('so', 'rotten'):0.014084507042253521
# ('rotten', 'that'):1.0
# ('should', 'all'):0.041666666666666664
# ('all', 'revolt'):0.013333333333333334
# ('revolt', 'and'):1.0
# ('and', 'suicid'):0.0023923444976076554
# ('suicid', 'out'):0.3333333333333333
# ('of', 'desper'):0.003424657534246575
# ('desper', 'or'):0.5
# ('or', 'kill'):0.014285714285714285
# ('kill', 'each'):0.125
# ('other', 'to'):0.045454545454545456
# ('put', 'an'):0.07692307692307693
# ('an', 'end'):0.018518518518518517
# ('end', 'to'):0.0625
# ('all', 'whi'):0.013333333333333334
# ('so', 'seriou'):0.014084507042253521
# ('seriou', 'ask'):0.3333333333333333
# ('ask', 'the'):0.25
# ('the', 'ledger'):0.0013908205841446453
# ('good', 'question'):0.01818181818181818
# ('question', 'becaus'):0.5
# ('in', 'worri'):0.005555555555555556
# ('worri', 'about'):1.0
# ('futur', 'of'):0.25
# ('charact', 'especi'):0.01639344262295082
# ('especi', 'for'):0.3333333333333333
# ('actor', 'who'):0.05555555555555555
# ('who', 'will'):0.03571428571428571
# ('will', 'want'):0.02564102564102564
# ('play', 'him'):0.0625
# ('him', 'in'):0.043478260869565216
# ('in', 'term'):0.005555555555555556
# ('term', 'of'):1.0
# ('actor', 'perform'):0.05555555555555555
# ('perform', 'that'):0.025
# ('that', 'joaquim'):0.00510204081632653
# ('joaquim', 'phoenix'):1.0
# ('phoenix', 'push'):0.016129032258064516
# ('push', 'to'):0.5
# ('the', 'extrem'):0.0013908205841446453
# ('extrem', 'all'):0.25
# ('over', 'in'):0.07142857142857142
# ('all', 'hi'):0.013333333333333334
# ('hi', 'film'):0.02
# ('i', 'rememb'):0.004405286343612335
# ('rememb', 'thi'):0.25
# ('thi', 'actor'):0.004366812227074236
# ('actor', 'play'):0.05555555555555555
# ('play', 'social'):0.0625
# ('social', 'visit'):0.3333333333333333
# ('visit', 'lover'):0.5
# ('lover', 'unabl'):1.0
# ('unabl', 'to'):1.0
# ('make', 'friend'):0.025
# ('friend', 'depress'):1.0
# ('depress', 'peopl'):0.2
# ('peopl', 'or'):0.02127659574468085
# ('or', 'on'):0.014285714285714285
# ('the', 'verg'):0.0013908205841446453
# ('verg', 'of'):1.0
# ('a', 'nervou'):0.0020242914979757085
# ('nervou', 'breakdown'):1.0
# ('breakdown', 'misunderstood'):1.0
# ('misunderstood', 'gun'):0.3333333333333333
# ('gun', 'son'):0.2
# ('son', 'reject'):0.3333333333333333
# ('reject', 'by'):0.5
# ('by', 'their'):0.018518518518518517
# ('their', 'father'):0.0625
# ('father', 'rebel'):1.0
# ('rebel', 'etc'):1.0
# ('etc', 'in'):0.25
# ('short', 'he'):0.14285714285714285
# ('he', 'onli'):0.012987012987012988
# ('onli', 'play'):0.037037037037037035
# ('play', 'tortur'):0.0625
# ('tortur', 'soul'):0.5
# ('soul', 'he'):1.0
# ('he', 'even'):0.012987012987012988
# ('even', 'play'):0.03225806451612903
# ('play', 'a'):0.125
# ('a', 'guy'):0.0020242914979757085
# ('guy', 'who'):0.14285714285714285
# ('who', 'fall'):0.03571428571428571
# ('hi', 'comput'):0.02
# ('comput', 'becaus'):1.0
# ('he', 'can'):0.012987012987012988
# ('get', 'along'):0.03225806451612903
# ('real', 'girlfriend'):0.06666666666666667
# ('girlfriend', 'so'):1.0
# ('so', 'it'):0.014084507042253521
# ('it', 'normal'):0.0026246719160104987
# ('normal', 'that'):0.3333333333333333
# ('he', 'know'):0.012987012987012988
# ('a', 'crazi'):0.0020242914979757085
# ('crazi', 'clown'):0.125
# ('clown', 'talent'):0.08333333333333333
# ('talent', 'if'):0.16666666666666666
# ('will', 'consid'):0.02564102564102564
# ('he', 'seem'):0.012987012987012988
# ('seem', 'unabl'):0.08333333333333333
# ('play', 'much'):0.0625
# ('much', 'el'):0.03571428571428571
# ('el', 'thi'):0.16666666666666666
# ('thi', 'simplist'):0.004366812227074236
# ('simplist', 'and'):1.0
# ('and', 'gloomi'):0.0023923444976076554
# ('gloomi', 'deduct'):1.0
# ('societi', 'ha'):0.058823529411764705
# ('ha', 'alreadi'):0.030303030303030304
# ('alreadi', 'claim'):0.2
# ('claim', 'victim'):0.2
# ('are', 'peopl'):0.015873015873015872
# ('who', 'dress'):0.03571428571428571
# ('dress', 'up'):1.0
# ('clown', 'and'):0.08333333333333333
# ('and', 'ransack'):0.0023923444976076554
# ('ransack', 'everyth'):1.0
# ('everyth', 'in'):0.08333333333333333
# ('the', 'street'):0.0013908205841446453
# ('street', 'and'):1.0
# ('and', 'cinema'):0.0023923444976076554
# ('cinema', 'where'):0.09090909090909091
# ('is', 'shown'):0.0033333333333333335
# ('shown', 'it'):0.3333333333333333
# ('some', 'visit'):0.03225806451612903
# ('visit', 'want'):0.5
# ('to', 'believ'):0.00303951367781155
# ('believ', 'that'):0.07142857142857142
# ('a', 'with'):0.0020242914979757085
# ('joke', 'their'):0.006211180124223602
# ('their', 'misfortun'):0.0625
# ('misfortun', 'depend'):1.0
# ('on', 'everyth'):0.014084507042253521
# ('everyth', 'and'):0.08333333333333333
# ('and', 'everyon'):0.0023923444976076554
# ('el', 'their'):0.16666666666666666
# ('their', 'happi'):0.0625
# ('happi', 'couldn'):0.2
# ('couldn', 'certainli'):0.16666666666666666
# ('certainli', 'be'):1.0
# ('be', 'up'):0.008547008547008548
# ('to', 'themselv'):0.00303951367781155
# ('themselv', 'anyway'):0.5
# ('anyway', 'dont'):0.3333333333333333
# ('dont', 'believ'):0.03225806451612903
# ('are', 'said'):0.015873015873015872
# ('said', 'about'):0.14285714285714285
# ('bit', 'out'):0.125
# ('of', 'sort'):0.003424657534246575
# ('sort', 'dont'):1.0
# ('dont', 'go'):0.03225806451612903
# ('make', 'yourself'):0.025
# ('yourself', 'more'):0.25
# ('more', 'unhappi'):0.0196078431372549
# ('unhappi', 'for'):1.0
# ('that', 'realli'):0.00510204081632653
# ('not', 'worth'):0.010309278350515464
# ('it', 'masterpiec'):0.0026246719160104987
# ('masterpiec', 'one'):0.05
# ('decad', 'it'):0.16666666666666666
# ('ha', 'it'):0.030303030303030304
# ('all', 'act'):0.013333333333333334
# ('direct', 'set'):0.0625
# ('set', 'photographi'):0.14285714285714285
# ('photographi', 'soundtrack'):1.0
# ('soundtrack', 'in'):0.25
# ('year', 'thi'):0.07142857142857142
# ('film', 'will'):0.011627906976744186
# ('a', 'cult'):0.0020242914979757085
# ('cult', 'one'):1.0
# ('one', 'it'):0.0196078431372549
# ('that', 'bore'):0.00510204081632653
# ('bore', 'realli'):0.05
# ('realli', 'can'):0.029411764705882353
# ('understand', 'what'):0.06666666666666667
# ('hope', 'is'):0.045454545454545456
# ('all', 'about'):0.013333333333333334
# ('about', 'one'):0.017857142857142856
# ('seen', 'ok'):0.034482758620689655
# ('ok', 'mayb'):0.5
# ('mayb', 'not'):0.1111111111111111
# ('they', 'hope'):0.03225806451612903
# ('hope', 'surround'):0.045454545454545456
# ('surround', 'the'):0.5
# ('movi', 'kill'):0.004310344827586207
# ('kill', 'it'):0.125
# ('but', 'an'):0.007874015748031496
# ('an', 'ok'):0.018518518518518517
# ('ok', 'film'):0.5
# ('film', 'whi'):0.011627906976744186
# ('whi', 'the'):0.05
# ('star', 'way'):0.125
# ('way', 'too'):0.030303030303030304
# ('mani', 'wa'):0.03225806451612903
# ('for', 'onc'):0.008403361344537815
# ('onc', 'i'):0.2
# ('actual', 'agre'):0.047619047619047616
# ('agre', 'with'):0.3333333333333333
# ('actual', 'critic'):0.047619047619047616
# ('critic', 'who'):0.125
# ('who', 'grade'):0.03571428571428571
# ('grade', 'thi'):0.3333333333333333
# ('didn', 'realli'):0.1
# ('know', 'much'):0.043478260869565216
# ('i', 'hadn'):0.004405286343612335
# ('hadn', 'seen'):0.5
# ('seen', 'ani'):0.034482758620689655
# ('ani', 'trailer'):0.047619047619047616
# ('or', 'anyth'):0.014285714285714285
# ('i', 'decid'):0.004405286343612335
# ('decid', 'to'):1.0
# ('give', 'it'):0.05
# ('a', 'go'):0.0020242914979757085
# ('go', 'while'):0.041666666666666664
# ('wa', 'stone'):0.0070921985815602835
# ('stone', 'with'):1.0
# ('my', 'mate'):0.06060606060606061
# ('mate', 'steve'):1.0
# ('steve', 'we'):0.5
# ('we', 'actual'):0.025
# ('actual', 'got'):0.047619047619047616
# ('got', 'ticket'):0.125
# ('ticket', 'for'):1.0
# ('differ', 'movi'):0.0625
# ('but', 'couldn'):0.007874015748031496
# ('couldn', 'find'):0.16666666666666666
# ('find', 'our'):0.2
# ('our', 'screen'):0.1111111111111111
# ('screen', 'so'):0.16666666666666666
# ('so', 'we'):0.014084507042253521
# ('we', 'end'):0.025
# ('up', 'in'):0.05
# ('screen', 'show'):0.16666666666666666
# ('want', 'til'):0.03225806451612903
# ('til', 'about'):1.0
# ('about', '45'):0.017857142857142856
# ('45', 'minut'):1.0
# ('minut', 'in'):0.2
# ('i', 'realis'):0.004405286343612335
# ('realis', 'thi'):1.0
# ('good', 'i'):0.01818181818181818
# ('couldn', 'understand'):0.16666666666666666
# ('understand', 'a'):0.06666666666666667
# ('what', 'certain'):0.018518518518518517
# ('certain', 'actor'):0.3333333333333333
# ('actor', 'were'):0.05555555555555555
# ('realli', 'mumbl'):0.029411764705882353
# ('mumbl', 'and'):1.0
# ('and', 'low'):0.0023923444976076554
# ('low', 'qualiti'):0.25
# ('qualiti', 'the'):0.25
# ('confus', 'it'):0.3333333333333333
# ('it', 'hard'):0.0026246719160104987
# ('to', 'keep'):0.0060790273556231
# ('keep', 'track'):0.08333333333333333
# ('track', 'of'):0.5
# ('who', 'who'):0.03571428571428571
# ('who', 'there'):0.03571428571428571
# ('of', 'scene'):0.003424657534246575
# ('scene', 'where'):0.05555555555555555
# ('where', 'liter'):0.09090909090909091
# ('peopl', 'talk'):0.02127659574468085
# ('talk', 'or'):0.16666666666666666
# ('or', 'walk'):0.014285714285714285
# ('walk', 'down'):0.25
# ('down', 'corridor'):0.1
# ('corridor', 'i'):1.0
# ('i', 'whisper'):0.004405286343612335
# ('whisper', 'to'):1.0
# ('to', 'my'):0.00303951367781155
# ('steve', 'about'):0.5
# ('about', 'an'):0.017857142857142856
# ('an', 'hour'):0.018518518518518517
# ('hour', 'in'):0.07692307692307693
# ('he', 'thought'):0.012987012987012988
# ('bad', 'a'):0.05263157894736842
# ('did', 'but'):0.058823529411764705
# ('had', 'fallen'):0.05263157894736842
# ('fallen', 'asleep'):1.0
# ('asleep', 'the'):0.5
# ('thing', 'about'):0.05
# ('the', 'deeper'):0.0013908205841446453
# ('deeper', 'who'):0.5
# ('who', 'play'):0.03571428571428571
# ('veri', 'good'):0.030303030303030304
# ('good', 'at'):0.01818181818181818
# ('few', 'veri'):0.14285714285714285
# ('veri', 'funni'):0.030303030303030304
# ('funni', 'scene'):0.3333333333333333
# ('scene', 'near'):0.05555555555555555
# ('end', 'but'):0.0625
# ('but', 'other'):0.007874015748031496
# ('than', 'that'):0.03333333333333333
# ('is', 'overlay'):0.0033333333333333335
# ('overlay', 'long'):0.25
# ('long', 'too'):0.09090909090909091
# ('too', 'complex'):0.05555555555555555
# ('complex', 'not'):0.5
# ('not', 'enough'):0.010309278350515464
# ('enough', 'action'):0.2
# ('direct', 'film'):0.0625
# ('wa', 'direct'):0.0070921985815602835
# ('direct', 'and'):0.0625
# ('and', 'produc'):0.0023923444976076554
# ('produc', 'poorli'):0.2
# ('poorli', 'opportun'):0.3333333333333333
# ('opportun', 'to'):0.3333333333333333
# ('take', 'advantag'):0.041666666666666664
# ('advantag', 'of'):1.0
# ('the', 'incred'):0.0013908205841446453
# ('incred', 'joaquin'):0.14285714285714285
# ('wa', 'blown'):0.0070921985815602835
# ('blown', 'gratuit'):1.0
# ('gratuit', 'violenc'):0.5
# ('violenc', 'misplac'):0.1
# ('misplac', 'violenc'):1.0
# ('violenc', 'wrong'):0.1
# ('wrong', 'approach'):0.1
# ('approach', 'to'):0.5
# ('joke', 'disappoint'):0.006211180124223602
# ('disappoint', 'connect'):0.25
# ('connect', 'to'):0.3333333333333333
# ('to', 'viewer'):0.00303951367781155
# ('viewer', 'film'):0.3333333333333333
# ('wa', 'wander'):0.0070921985815602835
# ('wander', 'for'):0.5
# ('for', 'long'):0.008403361344537815
# ('long', 'period'):0.09090909090909091
# ('period', 'ton'):0.5
# ('ton', 'of'):1.0
# ('of', 'forag'):0.003424657534246575
# ('forag', 'that'):1.0
# ('have', 'hit'):0.013888888888888888
# ('the', 'cut'):0.0013908205841446453
# ('cut', 'room'):0.3333333333333333
# ('room', 'floor'):1.0
# ('floor', 'i'):1.0
# ('realli', 'want'):0.029411764705882353
# ('want', 'an'):0.03225806451612903
# ('an', 'stir'):0.018518518518518517
# ('stir', 'creep'):1.0
# ('creep', 'connect'):1.0
# ('connect', 'with'):0.3333333333333333
# ('joaquin', 'a'):0.01818181818181818
# ('want', 'there'):0.03225806451612903
# ('there', 'if'):0.02127659574468085
# ('are', 'look'):0.015873015873015872
# ('joaquin', 'moment'):0.01818181818181818
# ('in', 'gladiat'):0.005555555555555556
# ('gladiat', 'you'):0.5
# ('veri', 'disappoint'):0.030303030303030304
# ('disappoint', 'now'):0.25
# ('to', 'admit'):0.00303951367781155
# ('admit', 'when'):1.0
# ('i', 'first'):0.004405286343612335
# ('first', 'heard'):0.07142857142857142
# ('heard', 'joaquin'):0.3333333333333333
# ('wa', 'go'):0.02127659574468085
# ('wa', 'surpris'):0.0070921985815602835
# ('surpris', 'i'):0.16666666666666666
# ('sure', 'how'):0.08333333333333333
# ('how', 'he'):0.03333333333333333
# ('pull', 'it'):0.3333333333333333
# ('it', 'off'):0.0026246719160104987
# ('off', 'i'):0.07692307692307693
# ('hope', 'it'):0.045454545454545456
# ('want', 'go'):0.03225806451612903
# ('be', 'anoth'):0.008547008547008548
# ('anoth', 'chees'):0.14285714285714285
# ('chees', 'condit'):0.5
# ('condit', 'full'):0.3333333333333333
# ('of', 'fluff'):0.003424657534246575
# ('fluff', 'and'):0.5
# ('realist', 'explan'):0.125
# ('explan', 'of'):1.0
# ('joke', 'came'):0.006211180124223602
# ('one', 'where'):0.0196078431372549
# ('where', 'my'):0.09090909090909091
# ('my', 'adult'):0.030303030303030304
# ('adult', 'son'):0.3333333333333333
# ('son', 'wouldn'):0.3333333333333333
# ('wouldn', 'have'):0.25
# ('keep', 'nudg'):0.08333333333333333
# ('nudg', 'me'):1.0
# ('to', 'wake'):0.00303951367781155
# ('wake', 'me'):0.3333333333333333
# ('me', 'up'):0.02857142857142857
# ('up', 'i'):0.05
# ('wa', 'pleasantli'):0.0070921985815602835
# ('pleasantli', 'surpris'):1.0
# ('surpris', 'on'):0.16666666666666666
# ('on', 'well'):0.014084507042253521
# ('well', 'told'):0.07692307692307693
# ('phillip', 'version'):0.1
# ('version', 'play'):0.09090909090909091
# ('play', 'and'):0.0625
# ('joaquin', 'act'):0.01818181818181818
# ('wa', 'superb'):0.0070921985815602835
# ('superb', 'you'):0.3333333333333333
# ('could', 'feel'):0.04
# ('feel', 'the'):0.02564102564102564
# ('the', 'anguish'):0.0013908205841446453
# ('anguish', 'hi'):1.0
# ('charact', 'wa'):0.01639344262295082
# ('through', 'right'):0.07692307692307693
# ('right', 'up'):0.1
# ('point', 'he'):0.05
# ('he', 'lost'):0.012987012987012988
# ('lost', 'hi'):0.3333333333333333
# ('mind', 'just'):0.2
# ('an', 'excel'):0.018518518518518517
# ('excel', 'well'):0.16666666666666666
# ('well', 'act'):0.07692307692307693
# ('act', 'movi'):0.023255813953488372
# ('you', 'almost'):0.01020408163265306
# ('almost', 'forget'):0.1
# ('forget', 'is'):0.2
# ('is', 'deriv'):0.0033333333333333335
# ('deriv', 'from'):1.0
# ('comic', 'thi'):0.043478260869565216
# ('is', 'poorli'):0.0033333333333333335
# ('poorli', 'done'):0.3333333333333333
# ('a', 'to'):0.0020242914979757085
# ('to', 'how'):0.00303951367781155
# ('it', 'tell'):0.0026246719160104987
# ('tell', 'the'):0.2
# ('stori', 'it'):0.02857142857142857
# ('dark', 'movi'):0.03571428571428571
# ('the', 'problem'):0.0013908205841446453
# ('problem', 'of'):0.25

# %%
ds = ''
index = []
i = 1
for line in df['Lemmatization']:
  ds = ds + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in df['Lemmatization']:
    noun_phrases_freq.append(line.count(word) / ds.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
#             everi onc  impact joaquin  ...  thi movi  dark movi show
# Review-1          1.0             1.0  ...  0.000000             0.0
# Review-2          0.0             0.0  ...  0.021505             0.0
# Review-3          0.0             0.0  ...  0.000000             0.0
# Review-4          0.0             0.0  ...  0.000000             0.0
# Review-5          0.0             0.0  ...  0.000000             0.0
# ...               ...             ...  ...       ...             ...
# Review-121        0.0             0.0  ...  0.032258             0.0
# Review-122        0.0             0.0  ...  0.000000             0.0
# Review-123        0.0             0.0  ...  0.000000             0.0
# Review-124        0.0             0.0  ...  0.000000             0.0
# Review-125        0.0             0.0  ...  0.010753             1.0
#
# [125 rows x 1421 columns]

# %% [markdown]
# Question 2: Undersand TF-IDF and Document representation
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the documents-terms weights (tf*idf) matrix bold text.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using cosine similarity.

# %%
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf = sentence.count(word)/size
  idf = 0
  if(tf!=0):
    idf = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf*idf

sentences = df["Correct Spellings"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sntncs:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda y : tf_idf_value(i,y))
  count+=1

tf_idf
# Out:
#                token         0         1  ...       122       123       124
# 0                     0.052748  0.054252  ...  0.057567  0.039123  0.136326
# 1             acting  0.000000  0.000000  ...  0.000000  0.039123  0.000000
# 2          represent  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3        heavyhanded  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4             depict  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# ...              ...       ...       ...  ...       ...       ...       ...
# 2361           value  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2362           grind  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2363  cinematography  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2364          slaves  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2365             far  0.052748  0.000000  ...  0.000000  0.000000  0.000000
#
# [2366 rows x 126 columns]

# %%
#Raising Cosine

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

query = 'I was so hyped up to see this movie, loved the trailer, only movie I have wanted to watch in the cinema for a very long time. I watched it and was bored. the aesthetics were amazing, music was good, story and execution was meh. the performance of the joker was a good performance but people raving about this are driving me mad. either you have not seen many movies or I have seen too many. this movie was bang average and was actually boring. I was actually thinking about leaving half way through as I was bored out of my mind. I do not regret watching it but it is being so overhyped that I am so confused right now. I think it had a good premise but could have been so much more, so much more. Signs of a great movie is the repeat viewing of it or it moving you, joker did not move me whatsoever and I would not watch it again. I thought maybe people are getting paid to write good review but have actually met people who think it is the best movie ever.... OMGGG This movie is bang average and way overhyped. phoenix performance is good but as the story and execution is so bad, I feel he never even touched the higher spectrum of performance he could have with the character. I have experienced and seen worse in my life, if this made you feel, you are (i hate this word but have to use it) a snowflake. Please get off social media and live life. there is a real world out there.'
X_list = word_tokenize(query)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

def compute_vector(X_set, Y_set):

  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]

  for w in rvector: 

      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)

  return rvector, l1, l2

def compute_cosine(rvector, l1, l2):

  c = 0
  for i in range(len(rvector)): 

        c+= l1[i]*l2[i] 

  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

similarity_list = []
for sentences in df['Correct Spellings']:

  Y_list = word_tokenize(sentences)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)

  try:
    similarity = compute_cosine(rvector, l1, l2)  

  except ZeroDivisionError:
    similarity = 'None'

  similarity_list.append(similarity)

cosine_df = pd.DataFrame(list(zip(df['The Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_df
# Out:
#                                                Reviews Cosine Similarity
# 0    Every once in a while a movie comes, that trul...          0.135434
# 1    This is a movie that only those who have felt ...          0.124367
# 2    Truly a masterpiece, The Best Hollywood film o...         0.0922331
# 3    Joaquin Phoenix gives a tour de force performa...         0.0629941
# 4    Most of the time movies are anticipated like t...          0.127515
# ..                                                 ...               ...
# 120  I didnt really know much about this movie. I h...          0.144338
# 121                                                                 None
# 122  Film was directed and produced poorly. Opportu...          0.049029
# 123  Wow, what a movie! I have to admit, When I fir...          0.101036
# 124  This movie is poorly done as to how it tells t...         0.0645497
#
# [125 rows x 2 columns]

# %%
pd.set_option('display.max_colwidth',1000)
pd.set_option('display.max_rows', 130)
df['The Review']
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Every once in a while a movie comes, that truly makes an impact. Joaquin's performance and scenography in all it's brilliance. Grotesque, haunting and cringy. Hard to watch at times,... but so mesmerizing, you won't blink an eye watching it. Tragic, but with seriously funny moments. Emotional rollercoaster - sometimes, with multiple emotions popping-up at the same time.\n\nthis is far from a typical action-riddled predictable super-hero movie - it's a proper psychological thriller/drama, with the single best character development I have ever seen.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    This is a movie that only those who have felt alone and isolated can truly relate to it. You understand the motive and you feel sorry for the character. A lot of people will see this movie and think that it encourages violence. But truly, this movie should encourage each and every one of us to become a better person, treat everyone with respect and make each other feel like they belong in this world, instead of making them feel isolated.
# 2                                                                                                                                               Truly a masterpiece, The Best Hollywood film of 2019, one of the Best films of the decade... And truly the Best film to bring a comic book so chillingly and realistically to real ife. Remarkable Direction, Cinematography, Music and the Acting. Some people are surprised to find it DISTURBING and VIOLENT, but it's a necessity and message. It's about society and reflects those underappreciated/unrecognized/bullied people, proving they can do something too. The way it shows class difference, corruption and how rich and talented rule others around them is not exaggerated and that's what makes it different. It's BELIEVABLE. There could be multiple JOKERs living in our society that could shake those around them in much bitter way than the film shows making people uncomforting people. Consider this a wake up call, a message, but first a film. A PERFECT film.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Joaquin Phoenix gives a tour de force performance, fearless and stunning in its emotional depth and physicality. It's impossible to talk about this without referencing Heath Ledger's Oscar-winning performance from The Dark Knight, widely considered the definitive live-action portrayal of the Joker, so let's talk about it. The fact is, everyone is going to be stunned by what Phoenix accomplishes, because it's what many thought impossible - a portrayal that matches and potentially exceeds that of The Dark Knight's Clown Prince of Crime
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Most of the time movies are anticipated like this they end up falling short, way short. Joker is the first time I was more than happy with the hype. Please ignore the complaints of "pernicious violence" as they are embarrassing to say the least. We haven't seen a comic movie this real before. If we ever "deserved" a better class of criminal - Phillips and Phoenix have delivered. This is dark, Joker IS dark and you will fall in love with the villain as you should. The bad guys are always more romantic anyway.
# 5                                                                                                                                                                   Let me start off by saying if Joaquin Phoneix doesn't get his Oscar for this movie. Then the Oscars should be cancelled. Phoneix is amazing as you might've heard from every review ever! But Todd Phillips. Is at his best here. The story lines he takes and visuals are just breathtaking. The score!! Omg the Score! Every time that score came on, I felt very uncomfortable, like something horrible was about to happen. It was GREAT. The Inspirations from Taxi Driver and King of Comedy are there, and add so much for the movie. And I got to be honest. There are scenes that are very violent. And its disturbing. But I honestly expected it to be WAYYYY more violent from all the controversy going on. Overall this movie was GREAT. Come Oscar season, it needs to be nominated for Best Picture, ScreenPlay, Cinematography, Actor, Score and Director
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I get why some people hate this . It's because of the political message and how some people think that you need get empathy for Arthur's madness. But come on that is not the point and it will never be. Enjoy this masterpiece because Joaquin Phoenix and Todd Phillips overdid themselves with this movie . The acting,music and cinematography are just amazing ! Please enjoy the movie without overthinking it.
# 7      I have seen Joker yesterday at Venice an early ill-fated screening. We had some trouble with audio that lead to a near-hour delay, but it definitely was worth it.\n\nJoker deserved to be presented at Venice Film Festival, an event that regards cinema as a form of art, because this film is far from a blockbuster or a mere entertainer movie, as most films in the genre are.\n\nIt focuses on the psyche of the main character, as it slowly crumbles under the pressure of society. And thus, Joaquin Phoenix does a wonderful performance, earning almost surely a nomination at the oscars at least. It's a take on the Joker that differs from Ledger's, but I'd say that both are equally as good. The main difference might be that Ledger's joker is a rational that acts insane, while Phoenix's is insane to the root.\n\nDespite being a movie about a superhero villain, Joker is much superior to most of the movies of the genre (I'd exclude the Dark Knight Trilogy only, but Joker is easily as good as Nol...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                         It's sad that Joaquin missed Oscar for 'The gladiator' as he was very compelling Villain. But I am quite confident he will win it for the 'Joker'. Damn what a movie !!! Keeps u on the toes all the time. Unpredictable storyline and really a deep interesting plot. Did I forget to mention acting ? Damn Do niro and Joaquin teach u what really is 5 star acting. To enjoy this movie, get a wine in your hand, close the curtains, turn of ur cellphones and put do not disturb sign on ur door. Best Dark thriller suspense movie you will get to experience.
# 9
# 10
# 11                                                                                                                                                                               This movie causes the audience to consider many topics on morality, particularly the poor choices made by the Joker. The Joker is more relatable in this movie than antagonists usually are. I think this gives a more realistic view of "bad" people, who are not usually 100% bad in all ways as society often judges. It is important to know when to sympathize with the Joker (towards the beginning of the movie), and when he needs to be identified as a threat (when he begins making certain bad choices). This movie is only suitable for adults who are willing to pick it apart and think critically about it. It isn't for light amusement. That substance is what makes it so good.\n\nIf you aren't able to ponder underlying themes on your own, and you have to be handed all your thoughts to you, then this isn't the best movie for you.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The acting, cinematography, sound design, and the script itself is phenomenal. This movie is a triumph. Joaquin Pheonix deserves an Oscar win for this tbh.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           The movie affects you in a way that makes it physically painful to experience, but in a good way.
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Need I say more? Everything about this Movie is Masterful in every single way! Joker isn't just an awesome comic book movie, it's an awesome movie, period. It offers no easy answers to the unsettling questions it raises about a cruel society in decline. Joaquin Phoenix's fully committed performance and Todd Phillips' masterful albeit loose reinvention of the DC source material make Joker a film that should leave comic book fans and non-fans alike disturbed and moved in all the right ways.
# 15     I quit relying on critic reviews years ago... I noticed for this movie that the critics ratings were low but viewer ratings were high. That being said, what is the point of a critic when for this movie, they are oh so wrong. I went and saw this tonite with my mom. I went in skeptical and w some what low expectations. I knew not to expect your typical super hero movie. What we got was a masterpiece. I went in expecting sheer boredom and I was instead on the edge of my seat the whole time. Not action edge of your seat, it was a fear of what he may do or say next edge of your seat. To see this character evolve into what we all know as the #1 villain of Batman was beyond genius and Joaquin Phoenix is a true master at perfecting the art of consuming himself into this character. I may be all over the place with this but I don't care. This movie, the story, the acting, directing, effects, everyone brought their A game and JP definitely deserves a nod and win for this role. And no, there i...
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              I will stop watching movies if Joaquin Phoenix is not awarded Oscar for his tremendous acting.
# 17                                                                                                                                                                                                                                                                                                                                                                                  I thought this film was good but I just don't get the hype personally. The acting was amazing and the film was good overall but I think 'masterpiece' and 'film of the year' are a bit overused throughout the reviews. In no way did I dislike this film, I thought it was really good, just overhyped. I feel as though a lot of the 10/10 reviews are purely based on the fact that it already has amazing reviews and so people want to carry the praise further and that it is about the joker. If this film was released and was about some random guy in the same situation, I don't think the reviews would be as high but maybe that's the point.
# 18
# 19                                                                                                                                                                                                      Do not really understand all the tens here. Sure, a good movie, good acting, nice shooting. But the plot is not so intriguing. At times it is really long and somewhat boring. I needed to double-check the genre to see if this is a drama or what. Crime, drama, thriller it said. I would put it maybe 90% in the drama and rest in thriller.\n\nI miss more dialogue, more depth, more substance. The plot is really not more then a somewhat crazy person becoming a bit crazier. Sure there is an undertone in that it is society and the system and the mean character of people that is bringing him down and creating the evil beast which later wants to destroy everything. Absolutely, but I think it is not intriguing story and plot and dialogue enough to give this a ten.\n\nWorthy of watching, yes. But not amazing
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            I went into this film expecting an all-time classic based on the reviews I had read & what I ended up watching was just a decent film overall. Phoenix is outstanding...so he definitely did his part. But I feel like if you've seen the trailers you've seen the movie because the best way I can describe this film is it feels like a 2 hour version of the trailer. At 2 hours it's a relatively common runtime, but it felt a lot longer...which isn't good. I'd say this is much more of a rental than a theater movie. Kinda just....eh.
# 21                                                                                                                                                                                                                  When I heard everyone saying that this is the film of the year and all the reviews flooding in with 10's, I was quite hyped and excited for this movie. When I walked out of the cinema, I felt hollow and empty.\n\nBefore I continue writing, let me say this, This is NOT the film of the year nor is it a real masterpiece. The cinematography is excellent and the acting is incredible, that's just it. The side-characters are bland and overly dramatic. The plot heavily relies on plot-twists and the film is so harsh that it actually falls flat on it's face.\n\nAre there no good points though? Phoenix is phenomenal and the score is great. The cinematography is also incredible but the plot is not that great at all. It even has plot holes and scenes that left me empty.\n\nFilm of the year? Nope.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This is just my opinion but I loved the Joker, the performances, cinematography, directing, style, all build a great story. And the acting from Phoenix was incredible, he done a great take for the iconic character, and wow does he commit, with loosing the weight for the role, to developing the laugh.
# 23     The recurring themes of so many of the 10 star reviews here should tell you a lot about this movie and its audience. If you can't get through a movie review without tossing in one or more claims that "THIS movie is so much better and smarter than YOUR superhero movie" (or even basing your entire review around this premise), then I hate to break it to you, but kid, you're nowhere near as intelligent and grown up as you think you are. This "my comic publisher is better than yours" BS should have been left behind on your grade school playground, it has absolutely no relevance to the quality of this movie, and your opinion of this movie should be considered highly suspect if you're in this group.\n\nI gotta say, if this movie was also your idea of the most perfect film ever made, you really need to get out more. Look, I get it. If you live in a safe little box where all you watch are superhero movies and mainstream blockbusters then I understand how exposure to themes like this for the...
# 24
# 25     I was so hyped up to see this movie, loved the trailer, only movie I have wanted to watch in the cinema for a very long time.\n\nI watched it and was bored. the aesthetics were amazing, music was good, story and execution was meh. the performance of the joker was a good performance but people raving about this are driving me mad. either you have not seen many movies or I have seen too many.\n\nthis movie was bang average and was actually boring. I was actually thinking about leaving half way through as I was bored out of my mind.\n\nI do not regret watching it but it is being so overhyped that I am so confused right now. I think it had a good premise but could have been so much more, so much more.\n\nSigns of a great movie is the repeat viewing of it or it moving you, joker did not move me whatsoever and I would not watch it again.\n\nI thought maybe people are getting paid to write good review but have actually met people who think it is the best movie ever.... OMGGG\n\nThis movie...
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                Joaquin Phoenix gives Heath Ledger a run for his money, true story. This is not a popcorn fluff comic book flick. DO NOT TAKE YOUR KIDS TO SEE THIS MOVIE. Shut down all ballots for the Oscar, Joaquin is taking that one home hands down. One of the best origin stories EVER put out. The only downside to this movie, is that it is a stand alone film that will have no sequels or ties to the DC Universe. Todd Philips take on the Joker is one of pure brilliance and Joaquin Phoenix was the Joker we deserved. He didn't steal from Jack or Heath but yet you got a taste of both.
# 27
# 28
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                 The music. The intense. The realism. The performance. The story. Such a perfect combination of everything. I never felt that a character like joker could be real until I saw this. Phoenix shows us what a joker is in our society and shows us how power can be obtained. Philips on the other hand had the perfect choice of music, camera angles, lighting and every important factor. Overall, I did not expect the story to be this perfect. Too many shocking turns happened and it really does represent today's society. If I was in the first screening, I would have applauded for 80 min not 8.
# 30                                                                        They say it's all in the writing. And this is a great example of that. Good acting and production values cannot save a script steeped in tiresome stereotypes and a failure to delve into a character's identity. We meet the Joker when already imbalanced and his so-called descent into madness is really a couple weeks away; far from a descent, it's a stroll. This is not a character study, despite claims to the contrary. It's a showcase of a good actor overly contorting his body and laughing manically as a mistaken expression of madness. Where is the past? Where are the influences? Where are the conflicts? What are the seminal moments that create the spiral? Perhaps if he had really had that relationship, and had it gone sour, it would justify a descent. Instead, it's a fait accompli. This is lazy writing, focused more on fancy long shots of Joaquin Phoenix dancing crazily than producing something of value to the franchise.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             A beyond pathetic Taxi Driver/King of Comedy rip-off borefest that is objectively the single worst/completely non-existent version of the "Joker" character in history.\n\nThe troll-worthy "masterpiece" reviews are the dictionary definition proof of how easy it is to fool the laughably clueless sheep.\n\nKeep crying about your "SOCIETY!!!!", cringey loser incels 🤣🤣🤣
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              The perfect portrait of a decline to insanity" & Joaquin Phoenix portrays this flawlessly in a performance of a lifetime. Choreographed impeccably by Todd Phillips & is nothing short of breathtaking. The cinematography & backdrop ideology of such an original film for such a complex character is only complimented by the superb soundtrack & acting. A hauntingly beautiful film & A Definate 10/10. Edit: Bring on part 2 plssssss!. We all want it!.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  It was a really slow paced and boring. It was too overhyped in my opinion.
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Phoenix convinces me that he has always meant to be the joker. The movie went beyond my expectations, so many emotions went through me these couple hours. I think because its rated R, Phoenix was able to unlock jokers full psychotic potential as the character he is meant to be. This was an AMAZING story, and it calls for more. And I mean a build up, a second movie, maybe one with batman? My hopes are too high at this point, but nevertheless, brilliant goddamn movie and THE BEST joker ever played hands down.
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            The pool does not need the money. They need the dignity and respect, coz that is what it takes to be a human. If you don't have that, money will only be a reminder of them being a "good boy". Like some politicians, they feel so frustrated when people from the lower class does not accept their funding champions. In this movie, through joker's life, I begin to get it.
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             I was expecting a masterpiece and oscar worthy film from all the hype. I actually didn't enjoy watching this movie. there was no message, it was slow and the joker turned out just to be the son of a schizophrenic and went crazy over a slight amount of bullying. I don't see how anyone could relate to this character and the laughing is lame acting way overdone. I'm just stunned that this has a 9/10 rating right now, how the hell?
# 37
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I thought this movie was complete and utter garbage. I don't understand why people liked this movie so much. The character doesn't even stay true to the comics and the director flat out said it didn't, and then they made it seem like it was part of Gothams fall and he was just a little boy that had a laughing problem... Hated it
# 39     10/10 Amazing story, Brilliant taking, magnificent cinematography. Someone had to step out of the safe game played by Superhero movies and Joker movie does just that (also The Boys). Movie is gritty, real, insanely dark and sometime quite disturbing to people who don't want accept what's shown in the movie is a terrible reality we face everyday if refused a proper care. Normally people start to compare the movie with one of the greatest like The Dark Knight and in acting wise to that of Heath ledger's Potrayal of joker. I wouldn't say this movie is better that that or otherwise , but it will stand tall amongst the greatest like The Godfather, Taxi Driver, Citizen Kane, The Dark Knight. Coming to the inevitable comparison of who's the better Joker? Heath or Joaquin. The answer is Both did a phenomenal job and the Joker character itself is fortunate to have being played by two greatest actors. Definitely a top contender for Oscars. I personally think it would take away 1.Best Actor 2...
# 40
# 41
# 42                                                                                                                                                                              The whole point of this movie is to bring attention to mental illness (I'll do you one better and name a bigger issue than mental illness that the film barely focuses on; the lack of quality mental healthcare) but the film completely discredits its own message with a one dimensional depiction of most of the world and characters that inhabit it. It seems that Gotham and its citizens (the entire universe for that matter) only exists to put Arthur down and considering the film isn't told from Arthur's perspective, it is a blatantly stupid depiction of the world. The reason why people liked it so much is because the sad corporate slaves (especially the youth currently being indoctrinated) were subconsciously tricked into believing they were part of some bigger cause when they were really just sitting in their comfy chairs.
# 43     Joaquin' portrayal of a sociopathic, mentally unstable man's transformation to the iconic Joker was non other than a grippingly accurate, realistic and touching rendition. A dark and disturbing character piece led by an Oscar worthy performance by Joaquin Phoenix. You really do feel bad for this guy, which makes it all the more heartbreaking when he inevitably becomes the clown prince of crime we all know and love, although we've never seen him like this. We see him suffer throughout the movie to the point we're almost rooting for himk to become a mass murdering psyco clown, because that at least will make feel better; then it happens and we just wish this could have all just been avoided, because es so messed up. We feel for him and care about him. By the time he's the joker, we wish we could've helped him. There's a lot of great nods to the greater Batman universe, yet the movie is a self contained character piece. That can only be the mark of a great movie. All the acting is gre...
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    One of the best movies in these few years and 100% Oscar worthy\n\nJoaquin Phoenix delivers one of the best performances I've ever scene
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Don't waste 2 hours of your life this movie is the baddest i've seen in a long time. Crappy writing and no good storyline...it was boring. I went to the pay counter to ask my money back for the 2 hours of torture...they can't do people like this. And for all the people with 10/10 (the reason why i went) you're a joke.
# 46                                                                                                                                                                                                          If it wasn't for the title and make-up, you wouldn't know it was based on the comic-book character. First of all, the real Joker is not a weak and unconfident pushover. Not even in his genesis stage. The real Joker had a high tolerance for pain, could fight and was intelligent. Which made him dangerous due to his insanity. When Joaquin shoots the guy on the subway, he does it out of cowardice. They try to make up for it with the Murray shooting scene. There is no way that Joaquin's Joker will ever fill the shoes of the badass Joker in the comics, not even the different incarnations by different comic authors....and just forget about even coming close to Heath Ledger's portrayal. They should have just called the movie something totally different and forget about trying to make the connection.
# ...
# 110
# 111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Acting, Cinematography, Music, Screenplay, Costumes, Gotham etc everything is 10/10.Oscar worthy performanceby by Joaquin Phoenix.Amazing directing by Todd Phillips & amazing cinematography by Lawrence Sher.
# 112                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          This was one of the worse movies I have seen. It was over acted by all actors, the story dragged on and on. I saw this movie for a bargain matinee and thought I was ripped off! The only good part was the comfy chairs and the half priced snacks! Phoenix was so over the top and not in a good way. PHOENIX STOP DANCING!!! Deniro played another version of all the parts he has played in the past few years! 2 stars for the chair and 1 star for the snacks, -1 stars for wasting my day!
# 113                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             I am not a Batman fan nor am I particularly fond of Joaquin Phoenix, but this movie was truly exceptional. It started slow but built to a viscerally satisfying crescendo. I never thought I would be rooting for the Joker, but found that I did so throughout the movie. The Joker's pain was so palpable. I am filling out my Oscar pool card right now.\n\nPS This movie is dark and violent and decidedly not a super hero movie. Leave the kids at home.
# 114    My husband and I went to see this film and found it extremely depressing. Moreover, everything is caricatured. What could be more normal, you might say, given that it was a depicting the life of a comic book clown? Christopher Nolan, the director of the famous Batman trilogy, said before it was produced that this movie would be useless. Simply because when it comes to horror, the less you show, the scarier it is. If you're told that there is a giant monster in the woods and it eats people, you'll laugh and not believe it or you'll imagine the most horrible monster there is; the most horrible according to you! What others show us is never as horrible for us as what we imagine. Here, to make things really awful, we sink into the worst possible melodrama. As if psychopaths had all been mistreated during their childhood, mocked in adolescence, misunderstood in adulthood without ever having anyone to help them effectively! But no, the vast majority of them were born with a missing bolt ...
# 115                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Masterpiece, one of the best films of the decade, it has it all, acting, directing, setting, photography, soundtrack, in a few years this film will be a cult one.
# 116
# 117                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               It's just that boring. really can't understand what the hype is all about??!
# 118
# 119                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          One of the worst movies I have ever seen. Ok, maybe not but they hype surrounding the movie killed it for me. It's not a masterpiece but an ok film. Why the one star? Way too many 10's! For once I actually agree with the actual critics who graded this film.
# 120             I didnt really know much about this movie. I hadnt seen any trailers for it or anything but i decided to give it a go while i was stoned with my mate Steve. we actually got tickets for a different movie but couldnt find our screen so we ended up in the screen showing The Joker. It wasnt til about 45 minutes in that I realised this movie is no good. I couldnt understand a lot of what certain actors were saying it was really mumbled and low quality. The story is so confusing its hard to keep track of who's who. There's a lot of scenes where literally nothing happens except for people talking or walking down corridors. I whispered to my mate Steve about an hour in to see if he thought it was as bad as i did, but he had fallen asleep.\n\nThe good thing about the movie is the acting. the geezer who plays the joker is very good at it. Also there is a few very funny scenes near the end but other than that this movie is overly long, too complex, not enough action, and poor directing.
# 121
# 122                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Film was directed and produced poorly. Opportunity to take advantage of the incredible Joaquin Phoenix was blown.\n\nGratuitous violence. Misplaced violence. Wrong approach to joker.\n\nDisappointing connection to viewer. Film was wandering for long periods. Tons of footage that should have hit the cutting room floor.\n\nI really wanted an stirringly creepy connection with Joaquin as Joker. It wasn't there.\n\nIf you are looking for Joaquin moment like in Gladiator, you will be very disappointed.
# 123                                                                                                                                                                                                                                                                                                                                                                 Wow, what a movie! I have to admit, When I first heard Joaquin Phoenix was going to be the joker, I was surprised. I wasn't sure how he was going to pull it off. I was hoping it wasn't going to be another cheesy rendition full of fluff and unrealistic explanations of how the Joker came to be. One where my (adult) son wouldn't have to keep nudging me to wake me up. I was pleasantly surprised on well Todd Phillips' version played and Joaquin's acting was superb. You could feel the anguish his character was going through right up to the point he lost his mind. Just an excellent, well acted movie that you almost forget is derived from a DC comic.
# 124                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This movie is poorly done as to how it tells the story. It is a dark movie showing the problem of mental illness
# Name: The Review, dtype: object

# %% [markdown]
# Question 3: Create your own training and evaluation data for sentiment analysis
# (15 points).
