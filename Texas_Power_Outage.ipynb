# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# Out:
# --2021-04-18 09:02:03--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   122MB/s    in 0.7s
#
# 2021-04-18 09:02:04 (122 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
# ...

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-xl6srzqe
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-xl6srzqe
# ...
#      |████████████████████████████████| 5.4 MB 6.7 MB/s
# ...
#      |████████████████████████████████| 115 kB 62.3 MB/s
# ...
#      |████████████████████████████████| 510 kB 28.6 MB/s
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev100+g39a34a5-py3-none-any.whl size=50455 sha256=45e89441765e9ea92518e3578aa2fc9160a3e800e5f9bd9922bc9efbccb1c42a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w0wfvxsu/wheels/92/42/87/33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# ...

# %%
import os

# Using OS library to call CLI commands in Python
os.system("snscrape --jsonl --max-results 50000 --since 2021-02-01 twitter-search 'texaspoweroutages until:2021-04-17' > Texas_Power_Outage.json")
# Out:
# 0

# %%
import pandas as pd

# Reads the json generated from the CLI commands above and creates a pandas dataframe
tweets_df = pd.read_json('Texas_Power_Outage.json', lines=True)
tweets_df
# Out:
#                                                      url  ... place
# 0      https://twitter.com/TheGreenITGuy/status/13830...  ...  None
# 1      https://twitter.com/SanAntoReview/status/13826...  ...  None
# 2      https://twitter.com/RealCarlBlair/status/13823...  ...  None
# 3      https://twitter.com/CynthiaEthelWo2/status/138...  ...  None
# 4      https://twitter.com/CynthiaEthelWo2/status/138...  ...  None
# ...                                                  ...  ...   ...
# 13320  https://twitter.com/alexrstockwell/status/1361...  ...  None
# 13321  https://twitter.com/cassiefavored/status/13615...  ...  None
# 13322  https://twitter.com/ShallowReality/status/1361...  ...  None
# 13323  https://twitter.com/GrosenbacherFR/status/1361...  ...  None
# 13324  https://twitter.com/KaraSewellTV/status/136128...  ...  None
#
# [13325 rows x 23 columns]

# %%
import pandas as pd

df = pd.read_json('/content/Texas_Power_Outage.json', lines=True)

# %%
df.dtypes
# Out:
# url                             object
# date               datetime64[ns, UTC]
# content                         object
# renderedContent                 object
# id                               int64
# user                            object
# outlinks                        object
# tcooutlinks                     object
# replyCount                       int64
# retweetCount                     int64
# likeCount                        int64
# quoteCount                       int64
# conversationId                   int64
# lang                            object
# source                          object
# sourceUrl                       object
# sourceLabel                     object
# media                           object
# retweetedTweet                 float64
# quotedTweet                     object
# mentionedUsers                  object
# coordinates                     object
# place                           object
# dtype: object

# %%
df['date'] = df['date'].dt.tz_localize(None)

# %%
df.to_excel ("poweroutage.xlsx")
