# %% [markdown]
# <a href="https://colab.research.google.com/github/AneesahAneesah/aneesah_INFO5731_Spring2021/blob/main/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/16/2020, 20 points in total)

# %% [markdown]
# The purpose of this exercise is to under users' information needs, then collect the data for analysis.

# %% [markdown]
# Question 1 (8 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
Question:
How many people are living in the second most populated country? What city is the most populated among all of them? 
Retrieve the details about any city from the given table. Is there any category the cities fit into according to their size?

Sol:
Although India is a smaller country compared to USA, Russia, Canada etc., it has rather huge population. Here we are going to see the population of all the cities of India. 
We are also going to see the population change, and these numbers are based on the census that was done in 2011. Also, the states or the union territories of these states.

Here, we will be using Webscraping to get the data we need. Beautiful soup is a package, which is used in parsing the HTML documents. It helps in extracting the data from HTML 
which is useful for webscraping. 

First, install the beautifulsoup package.
importing bs4 from beautiful soup so that the funtions of it can be used. 
As we are using website, permission is needed to query the website. A library called, urllib.request is imported.
Saving the website url into a variable.
Returning the HTML of the website into another variable to be stored. 

To make the document look presentable, we use a funtion called prettify(), so the HTML document is readable. 

The title of the website can be viewed through the HTML document using soup.title.
The links that were present and the titles of them can be viewed by using soup.find_all("a")
soup is a variable which stores the parsed HTML document in it. So when we search for title with (.) it gives us the searched query.
The connection between attributes and methods is represented by this operator. 
We can also find only the links that the website consists of, rather than all the titles and headers and footer. It is the users need.

After the HTML document is stored, the actual data needed is to be found. Here, it is a table which consists of the city names and the population in two different years(2001, 2011)
And also which state the city is from. We get the class of the table from the HTML document and assign it to a variable. The actual table needed(actual_T)

Through soup, we find the table with the help of class of the table. And store it in a variable. 

Extracting and saving the data with the help of data frames.
We generate lists which will store data of the elements(rows and columns) in it.
Using for loop, we iterate the data through each column and store it into the lists. 
We iterate with the help of the funtion findAll() which finds the rows(tr) columns(td) from the documents and stores them accordingly.
As we only have five columns we give a condition which will be satisfied if the length of the columns is five. ( As we only have five columns)
Appending the data we found in the rows and columns into the lists. 

Importing panda, and storing the data into the dataframes into columns. 
And printing them. 

'''
# Out:
# '\nPlease write you answer here:\nQuestion:\nHow many people are living in the second most populated country? What city is the most populated among all of them? \nRetrieve the details about any city from the given table. Is there any category the cities fit into according to their size?\n\nSol:\nAlthough India is a smaller country compared to USA, Russia, Canada etc., it has rather huge population. Here we are going to see the population of all the cities of India. \nWe are also going to see the population change, and these numbers are based on the census that was done in 2011. Also, the states or the union territories of these states \n\n\n\n\n\n\n'

# %% [markdown]
# Question 2 (12 points): Write python code to collect 500 items of the data you plan to collect above.

# %%
# You code here (Please add comments in the code):
# !pip install beautifulsoup4
import urllib.request
import re

W_pedia="https://en.wikipedia.org/wiki/List_of_cities_in_India_by_population"
pg=urllib.request.urlopen(W_pedia)

from bs4 import BeautifulSoup
soup=BeautifulSoup(pg)
print(soup.prettify())

#giving the class of the table from the html document

actual_T=soup.find('table', class_='wikitable sortable jquery-tablesorter')

#accessing the actual table that is to be used to give the information needed

print(actual_T)

#after finding the actual table that consists of the data, we extract the information from it
#and save that information

#using dataframes to extract and save the data
#lists are generated to save the data in for each columns of the table

soup.title

soup.find_all("a")

only_link= soup.find_all("a")

for just_link in only_link:
  print(just_link.get("href"))

#To be clear of the data to be retrived, we have to find the correct table 
#among all the tables that are present

tables=soup.find_all('table')

R=[]
C=[]
P1=[]
P2=[]
SU=[]

#the indexes of these will start from zero and end with n-1
#using for loop to iterate 'tr', where tr represents the rows in a table
#here, the rows and columns are being found for the data to be extrated from
soup
soup.find('table'), 
soup.find('table', id="datatable_main")

for i in actual_T.findAll("tr"):
  j=i.findAll('td') #td represents columns in a table
  state=i.findAll('th')  #th is used to store any second column data
  if len(j)==5:   #a conditional statement, 'if' is used to satisfy a condition, this is used to only extract the body of the table
    R.append(j[0].find(text=True))
    C.append(j[1].find(text=True))
    P1.append(j[2].find(text=True))
    P2.append(j[3].find(text=True))
    SU.append(j[4].find(text=True))

#printing the data of the extracted columns
print(R)
print(C)
print(P1)
print(P2)
print(SU)
# Out:
# Streaming output truncated to the last 5000 lines.
#          </td>
#          <td>
#           184,991
#          </td>
#          <td>
#           141,453
#          </td>
#          <td>
#           <a href="/wiki/Gujarat" title="Gujarat">
#            Gujarat
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           254
#          </td>
#          <td>
#           <a href="/wiki/Raiganj" title="Raiganj">
#            Raiganj
#           </a>
#          </td>
#          <td>
#           183,612
#          </td>
#          <td>
#           165,212
#          </td>
#          <td>
#           <a href="/wiki/West_Bengal" title="West Bengal">
#            West Bengal
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           255
#          </td>
#          <td>
#           <a href="/wiki/Sirsa" title="Sirsa">
#            Sirsa
#           </a>
#          </td>
#          <td>
#           182,534
#          </td>
# ...

# %%
#now that the required data has been extracted, we are going to make it into structured data
#into an actual table

import pandas as pnda

dataf=pnda.DataFrame(R,columns=['Rank'])
dataf['City']=C
dataf['Population1_2011']=P1
dataf['Population2_2001']=P2
dataf['State_or_Union_Territory']=SU

dataf
# Out:
# Empty DataFrame
# Columns: [Rank, City, Population1_2011, Population2_2001, State_or_Union_Territory]
# Index: []
