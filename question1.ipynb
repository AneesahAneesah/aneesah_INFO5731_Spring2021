# %%
import pandas as pd 
hospital_df = pd.read_csv('hospital.csv')
hospital_df
# Out:
#      state  ...                   Georeference
# 0       CO  ...   POINT (-105.883712 37.47236)
# 1       GA  ...                            NaN
# 2       LA  ...                            NaN
# 3       ME  ...                            NaN
# 4       MI  ...   POINT (-84.555111 42.704799)
# ...    ...  ...                            ...
# 5941    LA  ...   POINT (-91.094228 30.392207)
# 5942    PA  ...    POINT (-77.014432 41.24547)
# 5943    WA  ...  POINT (-122.323372 47.604084)
# 5944    FL  ...   POINT (-80.332412 25.900311)
# 5945    NC  ...   POINT (-77.920423 34.551263)
#
# [5946 rows x 97 columns]

# %%
hospital_df.describe()
# Out:
#            zip_code  fips_county  certified_bed_count  component_hospitals  \
# count   5946.000000  5946.000000          5946.000000          5902.000000
# mean   53896.272116    94.673226           155.537841             1.075059
# std    26924.808416   164.322068           204.734073             0.385676
# min      603.000000     0.000000             2.000000             1.000000
# 25%    32812.000000    31.000000            25.000000             1.000000
# 50%    55324.500000    69.000000            78.000000             1.000000
# 75%    76165.750000   119.000000           204.000000             1.000000
# max    99929.000000  9999.000000          3060.000000             8.000000
#
#        days_at_100%  percentage_of_required_fields_reported
# count   5946.000000                             5946.000000
# mean       6.875715                                0.983876
# std        0.786894                                0.107057
# ...

# %%
#creating a DataFrame
import numpy as np
df = pd.DataFrame(np.random.rand(10, 4), 
                  columns=('zip_code', 'fips_county', 'component_hospitals', 'percentage_of_required_fields_reported'))

# %%
#displaying the DataFrame
df
# Out:
#    zip_code  fips_county  component_hospitals  \
# 0  0.450272     0.529645             0.679872
# 1  0.982925     0.328235             0.589677
# 2  0.149200     0.331804             0.938809
# 3  0.543550     0.624796             0.720267
# 4  0.493325     0.505290             0.034612
# 5  0.477492     0.157958             0.393979
# 6  0.675927     0.833357             0.166823
# 7  0.743251     0.145463             0.804639
# 8  0.777286     0.882352             0.420805
# 9  0.140789     0.036192             0.977820
#
#    percentage_of_required_fields_reported
# 0                                0.880078
# 1                                0.441082
# 2                                0.223697
# 3                                0.380995
# 4                                0.581052
# 5                                0.555086
# 6                                0.861299
# 7                                0.096518
# 8                                0.010514
# ...

# %%
df.plot()

# %%
df.plot(kind="bar")

# %%
df.plot.barh(stacked=True);

# %%
df.plot.hist(stacked=True, bins=20);

# %%
df.plot.hist(orientation="horizontal", cumulative=True);

# %%
df.diff().hist();

# %%
df.plot.box()

# %%
df.plot.box(vert=False, positions=[1, 2, 3, 4]);

# %%
pie = pd.Series(np.random.rand(5))
pie.plot.pie();
pie
# Out:
# 0    0.692574
# 1    0.689260
# 2    0.403064
# 3    0.819382
# 4    0.024656
# dtype: float64
