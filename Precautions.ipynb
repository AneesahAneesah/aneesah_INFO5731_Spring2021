# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# Out:
# --2021-04-18 09:40:00--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   102MB/s    in 0.8s
#
# 2021-04-18 09:40:01 (102 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
# ...

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-popedna1
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-popedna1
# ...
#      |████████████████████████████████| 5.4 MB 7.9 MB/s
# ...
#      |████████████████████████████████| 115 kB 57.0 MB/s
# ...
#      |████████████████████████████████| 510 kB 49.2 MB/s
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev100+g39a34a5-py3-none-any.whl size=50455 sha256=c8796431c57989f958a5161786ff30f8ea626e4fe1ec6b7acab110122bec036c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aetk78lb/wheels/92/42/87/33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# ...

# %%
import os

# Using OS library to call CLI commands in Python
os.system("snscrape --jsonl --max-results 50000 --since 2021-02-11 twitter-search 'txwx until:2021-02-21' > Precautions.json")
# Out:
# 0

# %%
import pandas as pd

# Reads the json generated from the CLI commands above and creates a pandas dataframe
Precautions_df = pd.read_json('Precautions.json', lines=True)
Precautions_df
# Out:
#                                                      url  ... place
# 0      https://twitter.com/NWSFortWorth/status/136327...  ...  None
# 1      https://twitter.com/ConleyIsom/status/13632758...  ...  None
# 2      https://twitter.com/SpringTXWeather/status/136...  ...  None
# 3      https://twitter.com/RoshinRowjee/status/136327...  ...  None
# 4      https://twitter.com/theWeatherboy/status/13632...  ...  None
# ...                                                  ...  ...   ...
# 11270  https://twitter.com/mattlantz/status/135965343...  ...  None
# 11271  https://twitter.com/mattlantz/status/135965342...  ...  None
# 11272  https://twitter.com/JohnStasulli/status/135965...  ...  None
# 11273  https://twitter.com/lahwx/status/1359653381036...  ...  None
# 11274  https://twitter.com/albertquiles/status/135965...  ...  None
#
# [11275 rows x 23 columns]

# %%
import pandas as pd

Precautions = pd.read_json('/content/Precautions.json', lines=True)

# %%
Precautions.dtypes
# Out:
# url                             object
# date               datetime64[ns, UTC]
# content                         object
# renderedContent                 object
# id                               int64
# user                            object
# outlinks                        object
# tcooutlinks                     object
# replyCount                       int64
# retweetCount                     int64
# likeCount                        int64
# quoteCount                       int64
# conversationId                   int64
# lang                            object
# source                          object
# sourceUrl                       object
# sourceLabel                     object
# media                           object
# retweetedTweet                 float64
# quotedTweet                     object
# mentionedUsers                  object
# coordinates                     object
# place                           object
# dtype: object

# %%
Precautions['date'] = Precautions['date'].dt.tz_localize(None)

# %%
Precautions.to_excel ("Precautions.xlsx")
